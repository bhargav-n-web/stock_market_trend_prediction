# %% [markdown]
# # Importing libraries

# %%
#Importing the necessary libraries
import numpy as np
import pandas as pd
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, auc, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
import warnings
warnings.filterwarnings('ignore')
import datetime

# %% [markdown]
# # Importing data set

# %%
#Importing the dataset
df = pd.read_csv('000001.XSHE.csv')
df.head()       #df - raw dataset
# Out:
#    Unnamed: 0  open  close  high   low    volume       money   avg  \
# 0  2005-01-04  1.41   1.40  1.41  1.39   8204283  11465603.0  1.40
# 1  2005-01-05  1.40   1.39  1.41  1.36  15013006  20718559.0  1.38
# 2  2005-01-06  1.40   1.40  1.41  1.38  12423677  17333840.0  1.40
# 3  2005-01-07  1.41   1.40  1.42  1.39   8788185  12302853.0  1.40
# 4  2005-01-10  1.40   1.41  1.41  1.37  12263592  17111498.0  1.40
#
#    high_limit  low_limit  pre_close  paused    factor
# 0        1.56       1.27       1.41       0  0.214624
# 1        1.54       1.26       1.40       0  0.214624
# 2        1.53       1.25       1.39       0  0.214624
# 3        1.54       1.26       1.40       0  0.214624
# 4        1.54       1.26       1.40       0  0.214624

# %% [markdown]
# # Data preprocessing

# %%
#Renaming the unnamed columns
newdf = df.rename(columns={'Unnamed: 0':'Date','volume':'volume(x10^8)','money':'money(x10^8)'})

for i in range(df.shape[0]):
    newdf['volume(x10^8)'] = df['volume']/(10**8)
    newdf['money(x10^8)']  = df['money']/(10**8)

# %% [markdown]
# ## i) Checking and Handling Missing values

# %%
#Checking for missing values
start = datetime.date(2005,1,1) 
K = (2023-2005)*365 + 4 #No.of days
res = []                #List to store days from Jan 1 2005 to Jan 1 2023
for day in range(K):
	date = (start + datetime.timedelta(days = day)).isoformat()
	res.append(date)
aclist = list(newdf['Date'])     #List of days actually present in data set
id=0
msgdata = []     # List of Missing data and their indices
for i in res:
    msgele = []
    if i not in aclist:
        msgele.append(i)
        msgele.append(id)
        print(f"{i}(index-{id}) has missing data")
        msgdata.append(msgele)
    id+=1
# Out:
# 2005-01-01(index-0) has missing data
# 2005-01-02(index-1) has missing data
# 2005-01-03(index-2) has missing data
# 2005-01-08(index-7) has missing data
# 2005-01-09(index-8) has missing data
# 2005-01-15(index-14) has missing data
# 2005-01-16(index-15) has missing data
# 2005-01-22(index-21) has missing data
# 2005-01-23(index-22) has missing data
# 2005-01-29(index-28) has missing data
# 2005-01-30(index-29) has missing data
# 2005-02-05(index-35) has missing data
# 2005-02-06(index-36) has missing data
# 2005-02-07(index-37) has missing data
# 2005-02-08(index-38) has missing data
# 2005-02-09(index-39) has missing data
# 2005-02-10(index-40) has missing data
# 2005-02-11(index-41) has missing data
# 2005-02-12(index-42) has missing data
# 2005-02-13(index-43) has missing data
# 2005-02-14(index-44) has missing data
# 2005-02-15(index-45) has missing data
# 2005-02-19(index-49) has missing data
# 2005-02-20(index-50) has missing data
# 2005-02-26(index-56) has missing data
# 2005-02-27(index-57) has missing data
# 2005-03-05(index-63) has missing data
# 2005-03-06(index-64) has missing data
# 2005-03-12(index-70) has missing data
# 2005-03-13(index-71) has missing data
# 2005-03-19(index-77) has missing data
# 2005-03-20(index-78) has missing data
# 2005-03-26(index-84) has missing data
# 2005-03-27(index-85) has missing data
# 2005-04-02(index-91) has missing data
# 2005-04-03(index-92) has missing data
# 2005-04-09(index-98) has missing data
# 2005-04-10(index-99) has missing data
# 2005-04-16(index-105) has missing data
# 2005-04-17(index-106) has missing data
# 2005-04-23(index-112) has missing data
# 2005-04-24(index-113) has missing data
# 2005-04-30(index-119) has missing data
# 2005-05-01(index-120) has missing data
# 2005-05-02(index-121) has missing data
# 2005-05-03(index-122) has missing data
# 2005-05-04(index-123) has missing data
# 2005-05-05(index-124) has missing data
# 2005-05-06(index-125) has missing data
# 2005-05-07(index-126) has missing data
# 2005-05-08(index-127) has missing data
# 2005-05-14(index-133) has missing data
# 2005-05-15(index-134) has missing data
# 2005-05-21(index-140) has missing data
# 2005-05-22(index-141) has missing data
# 2005-05-28(index-147) has missing data
# 2005-05-29(index-148) has missing data
# 2005-06-04(index-154) has missing data
# 2005-06-05(index-155) has missing data
# 2005-06-11(index-161) has missing data
# 2005-06-12(index-162) has missing data
# 2005-06-18(index-168) has missing data
# 2005-06-19(index-169) has missing data
# 2005-06-25(index-175) has missing data
# 2005-06-26(index-176) has missing data
# 2005-07-02(index-182) has missing data
# 2005-07-03(index-183) has missing data
# 2005-07-09(index-189) has missing data
# 2005-07-10(index-190) has missing data
# 2005-07-16(index-196) has missing data
# 2005-07-17(index-197) has missing data
# 2005-07-23(index-203) has missing data
# 2005-07-24(index-204) has missing data
# 2005-07-30(index-210) has missing data
# 2005-07-31(index-211) has missing data
# 2005-08-06(index-217) has missing data
# 2005-08-07(index-218) has missing data
# 2005-08-13(index-224) has missing data
# 2005-08-14(index-225) has missing data
# 2005-08-20(index-231) has missing data
# 2005-08-21(index-232) has missing data
# 2005-08-27(index-238) has missing data
# 2005-08-28(index-239) has missing data
# 2005-09-03(index-245) has missing data
# 2005-09-04(index-246) has missing data
# 2005-09-10(index-252) has missing data
# 2005-09-11(index-253) has missing data
# 2005-09-17(index-259) has missing data
# 2005-09-18(index-260) has missing data
# 2005-09-24(index-266) has missing data
# 2005-09-25(index-267) has missing data
# 2005-10-01(index-273) has missing data
# 2005-10-02(index-274) has missing data
# 2005-10-03(index-275) has missing data
# 2005-10-04(index-276) has missing data
# 2005-10-05(index-277) has missing data
# 2005-10-06(index-278) has missing data
# 2005-10-07(index-279) has missing data
# 2005-10-08(index-280) has missing data
# 2005-10-09(index-281) has missing data
# 2005-10-15(index-287) has missing data
# 2005-10-16(index-288) has missing data
# 2005-10-22(index-294) has missing data
# 2005-10-23(index-295) has missing data
# 2005-10-29(index-301) has missing data
# 2005-10-30(index-302) has missing data
# 2005-11-05(index-308) has missing data
# 2005-11-06(index-309) has missing data
# 2005-11-12(index-315) has missing data
# 2005-11-13(index-316) has missing data
# 2005-11-19(index-322) has missing data
# 2005-11-20(index-323) has missing data
# 2005-11-26(index-329) has missing data
# 2005-11-27(index-330) has missing data
# 2005-12-03(index-336) has missing data
# 2005-12-04(index-337) has missing data
# 2005-12-10(index-343) has missing data
# 2005-12-11(index-344) has missing data
# 2005-12-17(index-350) has missing data
# 2005-12-18(index-351) has missing data
# 2005-12-24(index-357) has missing data
# 2005-12-25(index-358) has missing data
# 2005-12-31(index-364) has missing data
# 2006-01-01(index-365) has missing data
# 2006-01-02(index-366) has missing data
# 2006-01-03(index-367) has missing data
# 2006-01-07(index-371) has missing data
# 2006-01-08(index-372) has missing data
# 2006-01-14(index-378) has missing data
# 2006-01-15(index-379) has missing data
# 2006-01-21(index-385) has missing data
# 2006-01-22(index-386) has missing data
# 2006-01-26(index-390) has missing data
# 2006-01-27(index-391) has missing data
# 2006-01-28(index-392) has missing data
# 2006-01-29(index-393) has missing data
# 2006-01-30(index-394) has missing data
# 2006-01-31(index-395) has missing data
# 2006-02-01(index-396) has missing data
# 2006-02-02(index-397) has missing data
# 2006-02-03(index-398) has missing data
# 2006-02-04(index-399) has missing data
# 2006-02-05(index-400) has missing data
# 2006-02-11(index-406) has missing data
# 2006-02-12(index-407) has missing data
# 2006-02-18(index-413) has missing data
# 2006-02-19(index-414) has missing data
# 2006-02-25(index-420) has missing data
# 2006-02-26(index-421) has missing data
# 2006-03-04(index-427) has missing data
# 2006-03-05(index-428) has missing data
# 2006-03-11(index-434) has missing data
# 2006-03-12(index-435) has missing data
# 2006-03-18(index-441) has missing data
# 2006-03-19(index-442) has missing data
# 2006-03-25(index-448) has missing data
# 2006-03-26(index-449) has missing data
# 2006-04-01(index-455) has missing data
# 2006-04-02(index-456) has missing data
# 2006-04-08(index-462) has missing data
# 2006-04-09(index-463) has missing data
# 2006-04-15(index-469) has missing data
# 2006-04-16(index-470) has missing data
# 2006-04-22(index-476) has missing data
# 2006-04-23(index-477) has missing data
# 2006-04-29(index-483) has missing data
# 2006-04-30(index-484) has missing data
# 2006-05-01(index-485) has missing data
# 2006-05-02(index-486) has missing data
# 2006-05-03(index-487) has missing data
# 2006-05-04(index-488) has missing data
# 2006-05-05(index-489) has missing data
# 2006-05-06(index-490) has missing data
# 2006-05-07(index-491) has missing data
# 2006-05-13(index-497) has missing data
# 2006-05-14(index-498) has missing data
# 2006-05-20(index-504) has missing data
# 2006-05-21(index-505) has missing data
# 2006-05-27(index-511) has missing data
# 2006-05-28(index-512) has missing data
# 2006-06-03(index-518) has missing data
# 2006-06-04(index-519) has missing data
# 2006-06-10(index-525) has missing data
# 2006-06-11(index-526) has missing data
# 2006-06-17(index-532) has missing data
# 2006-06-18(index-533) has missing data
# 2006-06-24(index-539) has missing data
# 2006-06-25(index-540) has missing data
# 2006-07-01(index-546) has missing data
# 2006-07-02(index-547) has missing data
# 2006-07-08(index-553) has missing data
# 2006-07-09(index-554) has missing data
# 2006-07-15(index-560) has missing data
# 2006-07-16(index-561) has missing data
# 2006-07-22(index-567) has missing data
# 2006-07-23(index-568) has missing data
# 2006-07-29(index-574) has missing data
# 2006-07-30(index-575) has missing data
# 2006-08-05(index-581) has missing data
# 2006-08-06(index-582) has missing data
# 2006-08-12(index-588) has missing data
# 2006-08-13(index-589) has missing data
# 2006-08-19(index-595) has missing data
# 2006-08-20(index-596) has missing data
# 2006-08-26(index-602) has missing data
# 2006-08-27(index-603) has missing data
# 2006-09-02(index-609) has missing data
# 2006-09-03(index-610) has missing data
# 2006-09-09(index-616) has missing data
# 2006-09-10(index-617) has missing data
# 2006-09-16(index-623) has missing data
# 2006-09-17(index-624) has missing data
# 2006-09-23(index-630) has missing data
# 2006-09-24(index-631) has missing data
# 2006-09-30(index-637) has missing data
# 2006-10-01(index-638) has missing data
# 2006-10-02(index-639) has missing data
# 2006-10-03(index-640) has missing data
# 2006-10-04(index-641) has missing data
# 2006-10-05(index-642) has missing data
# 2006-10-06(index-643) has missing data
# 2006-10-07(index-644) has missing data
# 2006-10-08(index-645) has missing data
# 2006-10-14(index-651) has missing data
# 2006-10-15(index-652) has missing data
# 2006-10-21(index-658) has missing data
# 2006-10-22(index-659) has missing data
# 2006-10-28(index-665) has missing data
# 2006-10-29(index-666) has missing data
# 2006-11-04(index-672) has missing data
# 2006-11-05(index-673) has missing data
# 2006-11-11(index-679) has missing data
# 2006-11-12(index-680) has missing data
# 2006-11-18(index-686) has missing data
# 2006-11-19(index-687) has missing data
# 2006-11-25(index-693) has missing data
# 2006-11-26(index-694) has missing data
# 2006-12-02(index-700) has missing data
# 2006-12-03(index-701) has missing data
# 2006-12-09(index-707) has missing data
# 2006-12-10(index-708) has missing data
# 2006-12-16(index-714) has missing data
# 2006-12-17(index-715) has missing data
# 2006-12-23(index-721) has missing data
# 2006-12-24(index-722) has missing data
# 2006-12-30(index-728) has missing data
# 2006-12-31(index-729) has missing data
# 2007-01-01(index-730) has missing data
# 2007-01-02(index-731) has missing data
# 2007-01-03(index-732) has missing data
# 2007-01-06(index-735) has missing data
# 2007-01-07(index-736) has missing data
# 2007-01-13(index-742) has missing data
# 2007-01-14(index-743) has missing data
# 2007-01-20(index-749) has missing data
# 2007-01-21(index-750) has missing data
# 2007-01-27(index-756) has missing data
# 2007-01-28(index-757) has missing data
# 2007-02-03(index-763) has missing data
# 2007-02-04(index-764) has missing data
# 2007-02-10(index-770) has missing data
# 2007-02-11(index-771) has missing data
# 2007-02-17(index-777) has missing data
# 2007-02-18(index-778) has missing data
# 2007-02-19(index-779) has missing data
# 2007-02-20(index-780) has missing data
# 2007-02-21(index-781) has missing data
# 2007-02-22(index-782) has missing data
# 2007-02-23(index-783) has missing data
# 2007-02-24(index-784) has missing data
# 2007-02-25(index-785) has missing data
# 2007-03-03(index-791) has missing data
# 2007-03-04(index-792) has missing data
# 2007-03-10(index-798) has missing data
# 2007-03-11(index-799) has missing data
# 2007-03-17(index-805) has missing data
# 2007-03-18(index-806) has missing data
# 2007-03-24(index-812) has missing data
# 2007-03-25(index-813) has missing data
# 2007-03-31(index-819) has missing data
# 2007-04-01(index-820) has missing data
# 2007-04-07(index-826) has missing data
# 2007-04-08(index-827) has missing data
# 2007-04-14(index-833) has missing data
# 2007-04-15(index-834) has missing data
# 2007-04-21(index-840) has missing data
# 2007-04-22(index-841) has missing data
# 2007-04-28(index-847) has missing data
# 2007-04-29(index-848) has missing data
# 2007-05-01(index-850) has missing data
# 2007-05-02(index-851) has missing data
# 2007-05-03(index-852) has missing data
# 2007-05-04(index-853) has missing data
# 2007-05-05(index-854) has missing data
# 2007-05-06(index-855) has missing data
# 2007-05-07(index-856) has missing data
# 2007-05-12(index-861) has missing data
# 2007-05-13(index-862) has missing data
# 2007-05-19(index-868) has missing data
# 2007-05-20(index-869) has missing data
# 2007-05-26(index-875) has missing data
# 2007-05-27(index-876) has missing data
# 2007-06-02(index-882) has missing data
# 2007-06-03(index-883) has missing data
# 2007-06-09(index-889) has missing data
# 2007-06-10(index-890) has missing data
# 2007-06-16(index-896) has missing data
# 2007-06-17(index-897) has missing data
# 2007-06-23(index-903) has missing data
# 2007-06-24(index-904) has missing data
# 2007-06-30(index-910) has missing data
# 2007-07-01(index-911) has missing data
# 2007-07-07(index-917) has missing data
# 2007-07-08(index-918) has missing data
# 2007-07-14(index-924) has missing data
# 2007-07-15(index-925) has missing data
# 2007-07-21(index-931) has missing data
# 2007-07-22(index-932) has missing data
# 2007-07-28(index-938) has missing data
# 2007-07-29(index-939) has missing data
# 2007-08-04(index-945) has missing data
# 2007-08-05(index-946) has missing data
# 2007-08-11(index-952) has missing data
# 2007-08-12(index-953) has missing data
# 2007-08-18(index-959) has missing data
# 2007-08-19(index-960) has missing data
# 2007-08-25(index-966) has missing data
# 2007-08-26(index-967) has missing data
# 2007-09-01(index-973) has missing data
# 2007-09-02(index-974) has missing data
# 2007-09-08(index-980) has missing data
# 2007-09-09(index-981) has missing data
# 2007-09-15(index-987) has missing data
# 2007-09-16(index-988) has missing data
# 2007-09-22(index-994) has missing data
# 2007-09-23(index-995) has missing data
# 2007-09-29(index-1001) has missing data
# 2007-09-30(index-1002) has missing data
# 2007-10-01(index-1003) has missing data
# 2007-10-02(index-1004) has missing data
# 2007-10-03(index-1005) has missing data
# 2007-10-04(index-1006) has missing data
# 2007-10-05(index-1007) has missing data
# 2007-10-06(index-1008) has missing data
# 2007-10-07(index-1009) has missing data
# 2007-10-13(index-1015) has missing data
# 2007-10-14(index-1016) has missing data
# 2007-10-20(index-1022) has missing data
# 2007-10-21(index-1023) has missing data
# 2007-10-27(index-1029) has missing data
# 2007-10-28(index-1030) has missing data
# 2007-11-03(index-1036) has missing data
# 2007-11-04(index-1037) has missing data
# 2007-11-10(index-1043) has missing data
# 2007-11-11(index-1044) has missing data
# 2007-11-17(index-1050) has missing data
# 2007-11-18(index-1051) has missing data
# 2007-11-24(index-1057) has missing data
# 2007-11-25(index-1058) has missing data
# 2007-12-01(index-1064) has missing data
# 2007-12-02(index-1065) has missing data
# 2007-12-08(index-1071) has missing data
# 2007-12-09(index-1072) has missing data
# 2007-12-15(index-1078) has missing data
# 2007-12-16(index-1079) has missing data
# 2007-12-22(index-1085) has missing data
# 2007-12-23(index-1086) has missing data
# 2007-12-29(index-1092) has missing data
# 2007-12-30(index-1093) has missing data
# 2007-12-31(index-1094) has missing data
# 2008-01-01(index-1095) has missing data
# 2008-01-05(index-1099) has missing data
# 2008-01-06(index-1100) has missing data
# 2008-01-12(index-1106) has missing data
# 2008-01-13(index-1107) has missing data
# 2008-01-19(index-1113) has missing data
# 2008-01-20(index-1114) has missing data
# 2008-01-26(index-1120) has missing data
# 2008-01-27(index-1121) has missing data
# 2008-02-02(index-1127) has missing data
# 2008-02-03(index-1128) has missing data
# 2008-02-06(index-1131) has missing data
# 2008-02-07(index-1132) has missing data
# 2008-02-08(index-1133) has missing data
# 2008-02-09(index-1134) has missing data
# 2008-02-10(index-1135) has missing data
# 2008-02-11(index-1136) has missing data
# 2008-02-12(index-1137) has missing data
# 2008-02-16(index-1141) has missing data
# 2008-02-17(index-1142) has missing data
# 2008-02-23(index-1148) has missing data
# 2008-02-24(index-1149) has missing data
# 2008-03-01(index-1155) has missing data
# 2008-03-02(index-1156) has missing data
# 2008-03-08(index-1162) has missing data
# 2008-03-09(index-1163) has missing data
# 2008-03-15(index-1169) has missing data
# 2008-03-16(index-1170) has missing data
# 2008-03-22(index-1176) has missing data
# 2008-03-23(index-1177) has missing data
# 2008-03-29(index-1183) has missing data
# 2008-03-30(index-1184) has missing data
# 2008-04-04(index-1189) has missing data
# 2008-04-05(index-1190) has missing data
# 2008-04-06(index-1191) has missing data
# 2008-04-12(index-1197) has missing data
# 2008-04-13(index-1198) has missing data
# 2008-04-19(index-1204) has missing data
# 2008-04-20(index-1205) has missing data
# 2008-04-26(index-1211) has missing data
# 2008-04-27(index-1212) has missing data
# 2008-05-01(index-1216) has missing data
# 2008-05-02(index-1217) has missing data
# 2008-05-03(index-1218) has missing data
# 2008-05-04(index-1219) has missing data
# 2008-05-10(index-1225) has missing data
# 2008-05-11(index-1226) has missing data
# 2008-05-17(index-1232) has missing data
# 2008-05-18(index-1233) has missing data
# 2008-05-24(index-1239) has missing data
# 2008-05-25(index-1240) has missing data
# 2008-05-31(index-1246) has missing data
# 2008-06-01(index-1247) has missing data
# 2008-06-07(index-1253) has missing data
# 2008-06-08(index-1254) has missing data
# 2008-06-09(index-1255) has missing data
# 2008-06-14(index-1260) has missing data
# 2008-06-15(index-1261) has missing data
# 2008-06-21(index-1267) has missing data
# 2008-06-22(index-1268) has missing data
# 2008-06-28(index-1274) has missing data
# 2008-06-29(index-1275) has missing data
# 2008-07-05(index-1281) has missing data
# 2008-07-06(index-1282) has missing data
# 2008-07-12(index-1288) has missing data
# 2008-07-13(index-1289) has missing data
# 2008-07-19(index-1295) has missing data
# 2008-07-20(index-1296) has missing data
# 2008-07-26(index-1302) has missing data
# 2008-07-27(index-1303) has missing data
# 2008-08-02(index-1309) has missing data
# 2008-08-03(index-1310) has missing data
# 2008-08-09(index-1316) has missing data
# 2008-08-10(index-1317) has missing data
# 2008-08-16(index-1323) has missing data
# 2008-08-17(index-1324) has missing data
# 2008-08-23(index-1330) has missing data
# 2008-08-24(index-1331) has missing data
# 2008-08-30(index-1337) has missing data
# 2008-08-31(index-1338) has missing data
# 2008-09-06(index-1344) has missing data
# 2008-09-07(index-1345) has missing data
# 2008-09-13(index-1351) has missing data
# 2008-09-14(index-1352) has missing data
# 2008-09-15(index-1353) has missing data
# 2008-09-20(index-1358) has missing data
# 2008-09-21(index-1359) has missing data
# 2008-09-27(index-1365) has missing data
# 2008-09-28(index-1366) has missing data
# 2008-09-29(index-1367) has missing data
# 2008-09-30(index-1368) has missing data
# 2008-10-01(index-1369) has missing data
# 2008-10-02(index-1370) has missing data
# 2008-10-03(index-1371) has missing data
# 2008-10-04(index-1372) has missing data
# 2008-10-05(index-1373) has missing data
# 2008-10-11(index-1379) has missing data
# 2008-10-12(index-1380) has missing data
# 2008-10-18(index-1386) has missing data
# 2008-10-19(index-1387) has missing data
# 2008-10-25(index-1393) has missing data
# 2008-10-26(index-1394) has missing data
# 2008-11-01(index-1400) has missing data
# 2008-11-02(index-1401) has missing data
# 2008-11-08(index-1407) has missing data
# 2008-11-09(index-1408) has missing data
# 2008-11-15(index-1414) has missing data
# 2008-11-16(index-1415) has missing data
# 2008-11-22(index-1421) has missing data
# 2008-11-23(index-1422) has missing data
# 2008-11-29(index-1428) has missing data
# 2008-11-30(index-1429) has missing data
# 2008-12-06(index-1435) has missing data
# 2008-12-07(index-1436) has missing data
# 2008-12-13(index-1442) has missing data
# 2008-12-14(index-1443) has missing data
# 2008-12-20(index-1449) has missing data
# 2008-12-21(index-1450) has missing data
# 2008-12-27(index-1456) has missing data
# 2008-12-28(index-1457) has missing data
# 2009-01-01(index-1461) has missing data
# 2009-01-02(index-1462) has missing data
# 2009-01-03(index-1463) has missing data
# 2009-01-04(index-1464) has missing data
# 2009-01-10(index-1470) has missing data
# 2009-01-11(index-1471) has missing data
# 2009-01-17(index-1477) has missing data
# 2009-01-18(index-1478) has missing data
# 2009-01-24(index-1484) has missing data
# 2009-01-25(index-1485) has missing data
# 2009-01-26(index-1486) has missing data
# 2009-01-27(index-1487) has missing data
# 2009-01-28(index-1488) has missing data
# 2009-01-29(index-1489) has missing data
# 2009-01-30(index-1490) has missing data
# 2009-01-31(index-1491) has missing data
# 2009-02-01(index-1492) has missing data
# 2009-02-07(index-1498) has missing data
# 2009-02-08(index-1499) has missing data
# 2009-02-14(index-1505) has missing data
# 2009-02-15(index-1506) has missing data
# 2009-02-21(index-1512) has missing data
# 2009-02-22(index-1513) has missing data
# 2009-02-28(index-1519) has missing data
# 2009-03-01(index-1520) has missing data
# 2009-03-07(index-1526) has missing data
# 2009-03-08(index-1527) has missing data
# 2009-03-14(index-1533) has missing data
# 2009-03-15(index-1534) has missing data
# 2009-03-21(index-1540) has missing data
# 2009-03-22(index-1541) has missing data
# 2009-03-28(index-1547) has missing data
# 2009-03-29(index-1548) has missing data
# 2009-04-04(index-1554) has missing data
# 2009-04-05(index-1555) has missing data
# 2009-04-06(index-1556) has missing data
# 2009-04-11(index-1561) has missing data
# 2009-04-12(index-1562) has missing data
# 2009-04-18(index-1568) has missing data
# 2009-04-19(index-1569) has missing data
# 2009-04-25(index-1575) has missing data
# 2009-04-26(index-1576) has missing data
# 2009-05-01(index-1581) has missing data
# 2009-05-02(index-1582) has missing data
# 2009-05-03(index-1583) has missing data
# 2009-05-09(index-1589) has missing data
# 2009-05-10(index-1590) has missing data
# 2009-05-16(index-1596) has missing data
# 2009-05-17(index-1597) has missing data
# 2009-05-23(index-1603) has missing data
# 2009-05-24(index-1604) has missing data
# 2009-05-28(index-1608) has missing data
# 2009-05-29(index-1609) has missing data
# 2009-05-30(index-1610) has missing data
# 2009-05-31(index-1611) has missing data
# 2009-06-06(index-1617) has missing data
# 2009-06-07(index-1618) has missing data
# 2009-06-13(index-1624) has missing data
# 2009-06-14(index-1625) has missing data
# 2009-06-20(index-1631) has missing data
# 2009-06-21(index-1632) has missing data
# 2009-06-27(index-1638) has missing data
# 2009-06-28(index-1639) has missing data
# 2009-07-04(index-1645) has missing data
# 2009-07-05(index-1646) has missing data
# 2009-07-11(index-1652) has missing data
# 2009-07-12(index-1653) has missing data
# 2009-07-18(index-1659) has missing data
# 2009-07-19(index-1660) has missing data
# 2009-07-25(index-1666) has missing data
# 2009-07-26(index-1667) has missing data
# 2009-08-01(index-1673) has missing data
# 2009-08-02(index-1674) has missing data
# 2009-08-08(index-1680) has missing data
# 2009-08-09(index-1681) has missing data
# 2009-08-15(index-1687) has missing data
# 2009-08-16(index-1688) has missing data
# 2009-08-22(index-1694) has missing data
# 2009-08-23(index-1695) has missing data
# 2009-08-29(index-1701) has missing data
# 2009-08-30(index-1702) has missing data
# 2009-09-05(index-1708) has missing data
# 2009-09-06(index-1709) has missing data
# 2009-09-12(index-1715) has missing data
# 2009-09-13(index-1716) has missing data
# 2009-09-19(index-1722) has missing data
# 2009-09-20(index-1723) has missing data
# 2009-09-26(index-1729) has missing data
# 2009-09-27(index-1730) has missing data
# 2009-10-01(index-1734) has missing data
# 2009-10-02(index-1735) has missing data
# 2009-10-03(index-1736) has missing data
# 2009-10-04(index-1737) has missing data
# 2009-10-05(index-1738) has missing data
# 2009-10-06(index-1739) has missing data
# 2009-10-07(index-1740) has missing data
# 2009-10-08(index-1741) has missing data
# 2009-10-10(index-1743) has missing data
# 2009-10-11(index-1744) has missing data
# 2009-10-17(index-1750) has missing data
# 2009-10-18(index-1751) has missing data
# 2009-10-24(index-1757) has missing data
# 2009-10-25(index-1758) has missing data
# 2009-10-31(index-1764) has missing data
# 2009-11-01(index-1765) has missing data
# 2009-11-07(index-1771) has missing data
# 2009-11-08(index-1772) has missing data
# 2009-11-14(index-1778) has missing data
# 2009-11-15(index-1779) has missing data
# 2009-11-21(index-1785) has missing data
# 2009-11-22(index-1786) has missing data
# 2009-11-28(index-1792) has missing data
# 2009-11-29(index-1793) has missing data
# 2009-12-05(index-1799) has missing data
# 2009-12-06(index-1800) has missing data
# 2009-12-12(index-1806) has missing data
# 2009-12-13(index-1807) has missing data
# 2009-12-19(index-1813) has missing data
# 2009-12-20(index-1814) has missing data
# 2009-12-26(index-1820) has missing data
# 2009-12-27(index-1821) has missing data
# 2010-01-01(index-1826) has missing data
# 2010-01-02(index-1827) has missing data
# 2010-01-03(index-1828) has missing data
# 2010-01-09(index-1834) has missing data
# 2010-01-10(index-1835) has missing data
# 2010-01-16(index-1841) has missing data
# 2010-01-17(index-1842) has missing data
# 2010-01-23(index-1848) has missing data
# 2010-01-24(index-1849) has missing data
# 2010-01-30(index-1855) has missing data
# 2010-01-31(index-1856) has missing data
# 2010-02-06(index-1862) has missing data
# 2010-02-07(index-1863) has missing data
# 2010-02-13(index-1869) has missing data
# 2010-02-14(index-1870) has missing data
# 2010-02-15(index-1871) has missing data
# 2010-02-16(index-1872) has missing data
# 2010-02-17(index-1873) has missing data
# 2010-02-18(index-1874) has missing data
# 2010-02-19(index-1875) has missing data
# 2010-02-20(index-1876) has missing data
# 2010-02-21(index-1877) has missing data
# 2010-02-27(index-1883) has missing data
# 2010-02-28(index-1884) has missing data
# 2010-03-06(index-1890) has missing data
# 2010-03-07(index-1891) has missing data
# 2010-03-13(index-1897) has missing data
# 2010-03-14(index-1898) has missing data
# 2010-03-20(index-1904) has missing data
# 2010-03-21(index-1905) has missing data
# 2010-03-27(index-1911) has missing data
# 2010-03-28(index-1912) has missing data
# 2010-04-03(index-1918) has missing data
# 2010-04-04(index-1919) has missing data
# 2010-04-05(index-1920) has missing data
# 2010-04-10(index-1925) has missing data
# 2010-04-11(index-1926) has missing data
# 2010-04-17(index-1932) has missing data
# 2010-04-18(index-1933) has missing data
# 2010-04-24(index-1939) has missing data
# 2010-04-25(index-1940) has missing data
# 2010-05-01(index-1946) has missing data
# 2010-05-02(index-1947) has missing data
# 2010-05-03(index-1948) has missing data
# 2010-05-08(index-1953) has missing data
# 2010-05-09(index-1954) has missing data
# 2010-05-15(index-1960) has missing data
# 2010-05-16(index-1961) has missing data
# 2010-05-22(index-1967) has missing data
# 2010-05-23(index-1968) has missing data
# 2010-05-29(index-1974) has missing data
# 2010-05-30(index-1975) has missing data
# 2010-06-05(index-1981) has missing data
# 2010-06-06(index-1982) has missing data
# 2010-06-12(index-1988) has missing data
# 2010-06-13(index-1989) has missing data
# 2010-06-14(index-1990) has missing data
# 2010-06-15(index-1991) has missing data
# 2010-06-16(index-1992) has missing data
# 2010-06-19(index-1995) has missing data
# 2010-06-20(index-1996) has missing data
# 2010-06-26(index-2002) has missing data
# 2010-06-27(index-2003) has missing data
# 2010-07-03(index-2009) has missing data
# 2010-07-04(index-2010) has missing data
# 2010-07-10(index-2016) has missing data
# 2010-07-11(index-2017) has missing data
# 2010-07-17(index-2023) has missing data
# 2010-07-18(index-2024) has missing data
# 2010-07-24(index-2030) has missing data
# 2010-07-25(index-2031) has missing data
# 2010-07-31(index-2037) has missing data
# 2010-08-01(index-2038) has missing data
# 2010-08-07(index-2044) has missing data
# 2010-08-08(index-2045) has missing data
# 2010-08-14(index-2051) has missing data
# 2010-08-15(index-2052) has missing data
# 2010-08-21(index-2058) has missing data
# 2010-08-22(index-2059) has missing data
# 2010-08-28(index-2065) has missing data
# 2010-08-29(index-2066) has missing data
# 2010-09-04(index-2072) has missing data
# 2010-09-05(index-2073) has missing data
# 2010-09-11(index-2079) has missing data
# 2010-09-12(index-2080) has missing data
# 2010-09-18(index-2086) has missing data
# 2010-09-19(index-2087) has missing data
# 2010-09-22(index-2090) has missing data
# 2010-09-23(index-2091) has missing data
# 2010-09-24(index-2092) has missing data
# 2010-09-25(index-2093) has missing data
# 2010-09-26(index-2094) has missing data
# 2010-10-01(index-2099) has missing data
# 2010-10-02(index-2100) has missing data
# 2010-10-03(index-2101) has missing data
# 2010-10-04(index-2102) has missing data
# 2010-10-05(index-2103) has missing data
# 2010-10-06(index-2104) has missing data
# 2010-10-07(index-2105) has missing data
# 2010-10-09(index-2107) has missing data
# 2010-10-10(index-2108) has missing data
# 2010-10-16(index-2114) has missing data
# 2010-10-17(index-2115) has missing data
# 2010-10-23(index-2121) has missing data
# 2010-10-24(index-2122) has missing data
# 2010-10-30(index-2128) has missing data
# 2010-10-31(index-2129) has missing data
# 2010-11-06(index-2135) has missing data
# 2010-11-07(index-2136) has missing data
# 2010-11-13(index-2142) has missing data
# 2010-11-14(index-2143) has missing data
# 2010-11-20(index-2149) has missing data
# 2010-11-21(index-2150) has missing data
# 2010-11-27(index-2156) has missing data
# 2010-11-28(index-2157) has missing data
# 2010-12-04(index-2163) has missing data
# 2010-12-05(index-2164) has missing data
# 2010-12-11(index-2170) has missing data
# 2010-12-12(index-2171) has missing data
# 2010-12-18(index-2177) has missing data
# 2010-12-19(index-2178) has missing data
# 2010-12-25(index-2184) has missing data
# 2010-12-26(index-2185) has missing data
# 2011-01-01(index-2191) has missing data
# 2011-01-02(index-2192) has missing data
# 2011-01-03(index-2193) has missing data
# 2011-01-08(index-2198) has missing data
# 2011-01-09(index-2199) has missing data
# 2011-01-15(index-2205) has missing data
# 2011-01-16(index-2206) has missing data
# 2011-01-22(index-2212) has missing data
# 2011-01-23(index-2213) has missing data
# 2011-01-29(index-2219) has missing data
# 2011-01-30(index-2220) has missing data
# 2011-02-02(index-2223) has missing data
# 2011-02-03(index-2224) has missing data
# 2011-02-04(index-2225) has missing data
# 2011-02-05(index-2226) has missing data
# 2011-02-06(index-2227) has missing data
# 2011-02-07(index-2228) has missing data
# 2011-02-08(index-2229) has missing data
# 2011-02-12(index-2233) has missing data
# 2011-02-13(index-2234) has missing data
# 2011-02-19(index-2240) has missing data
# 2011-02-20(index-2241) has missing data
# 2011-02-26(index-2247) has missing data
# 2011-02-27(index-2248) has missing data
# 2011-03-05(index-2254) has missing data
# 2011-03-06(index-2255) has missing data
# 2011-03-12(index-2261) has missing data
# 2011-03-13(index-2262) has missing data
# 2011-03-19(index-2268) has missing data
# 2011-03-20(index-2269) has missing data
# 2011-03-26(index-2275) has missing data
# 2011-03-27(index-2276) has missing data
# 2011-04-02(index-2282) has missing data
# 2011-04-03(index-2283) has missing data
# 2011-04-04(index-2284) has missing data
# 2011-04-05(index-2285) has missing data
# 2011-04-09(index-2289) has missing data
# 2011-04-10(index-2290) has missing data
# 2011-04-16(index-2296) has missing data
# 2011-04-17(index-2297) has missing data
# 2011-04-23(index-2303) has missing data
# 2011-04-24(index-2304) has missing data
# 2011-04-30(index-2310) has missing data
# 2011-05-01(index-2311) has missing data
# 2011-05-02(index-2312) has missing data
# 2011-05-07(index-2317) has missing data
# 2011-05-08(index-2318) has missing data
# 2011-05-14(index-2324) has missing data
# 2011-05-15(index-2325) has missing data
# 2011-05-21(index-2331) has missing data
# 2011-05-22(index-2332) has missing data
# 2011-05-28(index-2338) has missing data
# 2011-05-29(index-2339) has missing data
# 2011-06-04(index-2345) has missing data
# 2011-06-05(index-2346) has missing data
# 2011-06-06(index-2347) has missing data
# 2011-06-11(index-2352) has missing data
# 2011-06-12(index-2353) has missing data
# 2011-06-18(index-2359) has missing data
# 2011-06-19(index-2360) has missing data
# 2011-06-25(index-2366) has missing data
# 2011-06-26(index-2367) has missing data
# 2011-07-02(index-2373) has missing data
# 2011-07-03(index-2374) has missing data
# 2011-07-09(index-2380) has missing data
# 2011-07-10(index-2381) has missing data
# 2011-07-16(index-2387) has missing data
# 2011-07-17(index-2388) has missing data
# 2011-07-23(index-2394) has missing data
# 2011-07-24(index-2395) has missing data
# 2011-07-30(index-2401) has missing data
# 2011-07-31(index-2402) has missing data
# 2011-08-06(index-2408) has missing data
# 2011-08-07(index-2409) has missing data
# 2011-08-13(index-2415) has missing data
# 2011-08-14(index-2416) has missing data
# 2011-08-20(index-2422) has missing data
# 2011-08-21(index-2423) has missing data
# 2011-08-27(index-2429) has missing data
# 2011-08-28(index-2430) has missing data
# 2011-09-03(index-2436) has missing data
# 2011-09-04(index-2437) has missing data
# 2011-09-10(index-2443) has missing data
# 2011-09-11(index-2444) has missing data
# 2011-09-12(index-2445) has missing data
# 2011-09-17(index-2450) has missing data
# 2011-09-18(index-2451) has missing data
# 2011-09-24(index-2457) has missing data
# 2011-09-25(index-2458) has missing data
# 2011-10-01(index-2464) has missing data
# 2011-10-02(index-2465) has missing data
# 2011-10-03(index-2466) has missing data
# 2011-10-04(index-2467) has missing data
# 2011-10-05(index-2468) has missing data
# 2011-10-06(index-2469) has missing data
# 2011-10-07(index-2470) has missing data
# 2011-10-08(index-2471) has missing data
# 2011-10-09(index-2472) has missing data
# 2011-10-15(index-2478) has missing data
# 2011-10-16(index-2479) has missing data
# 2011-10-22(index-2485) has missing data
# 2011-10-23(index-2486) has missing data
# 2011-10-29(index-2492) has missing data
# 2011-10-30(index-2493) has missing data
# 2011-11-05(index-2499) has missing data
# 2011-11-06(index-2500) has missing data
# 2011-11-12(index-2506) has missing data
# 2011-11-13(index-2507) has missing data
# 2011-11-19(index-2513) has missing data
# 2011-11-20(index-2514) has missing data
# 2011-11-26(index-2520) has missing data
# 2011-11-27(index-2521) has missing data
# 2011-12-03(index-2527) has missing data
# 2011-12-04(index-2528) has missing data
# 2011-12-10(index-2534) has missing data
# 2011-12-11(index-2535) has missing data
# 2011-12-17(index-2541) has missing data
# 2011-12-18(index-2542) has missing data
# 2011-12-24(index-2548) has missing data
# 2011-12-25(index-2549) has missing data
# 2011-12-31(index-2555) has missing data
# 2012-01-01(index-2556) has missing data
# 2012-01-02(index-2557) has missing data
# 2012-01-03(index-2558) has missing data
# 2012-01-07(index-2562) has missing data
# 2012-01-08(index-2563) has missing data
# 2012-01-14(index-2569) has missing data
# 2012-01-15(index-2570) has missing data
# 2012-01-21(index-2576) has missing data
# 2012-01-22(index-2577) has missing data
# 2012-01-23(index-2578) has missing data
# 2012-01-24(index-2579) has missing data
# 2012-01-25(index-2580) has missing data
# 2012-01-26(index-2581) has missing data
# 2012-01-27(index-2582) has missing data
# 2012-01-28(index-2583) has missing data
# 2012-01-29(index-2584) has missing data
# 2012-02-04(index-2590) has missing data
# 2012-02-05(index-2591) has missing data
# 2012-02-11(index-2597) has missing data
# 2012-02-12(index-2598) has missing data
# 2012-02-18(index-2604) has missing data
# 2012-02-19(index-2605) has missing data
# 2012-02-25(index-2611) has missing data
# 2012-02-26(index-2612) has missing data
# 2012-03-03(index-2618) has missing data
# 2012-03-04(index-2619) has missing data
# 2012-03-10(index-2625) has missing data
# 2012-03-11(index-2626) has missing data
# 2012-03-17(index-2632) has missing data
# 2012-03-18(index-2633) has missing data
# 2012-03-24(index-2639) has missing data
# 2012-03-25(index-2640) has missing data
# 2012-03-31(index-2646) has missing data
# 2012-04-01(index-2647) has missing data
# 2012-04-02(index-2648) has missing data
# 2012-04-03(index-2649) has missing data
# 2012-04-04(index-2650) has missing data
# 2012-04-07(index-2653) has missing data
# 2012-04-08(index-2654) has missing data
# 2012-04-14(index-2660) has missing data
# 2012-04-15(index-2661) has missing data
# 2012-04-21(index-2667) has missing data
# 2012-04-22(index-2668) has missing data
# 2012-04-28(index-2674) has missing data
# 2012-04-29(index-2675) has missing data
# 2012-04-30(index-2676) has missing data
# 2012-05-01(index-2677) has missing data
# 2012-05-05(index-2681) has missing data
# 2012-05-06(index-2682) has missing data
# 2012-05-12(index-2688) has missing data
# 2012-05-13(index-2689) has missing data
# 2012-05-19(index-2695) has missing data
# 2012-05-20(index-2696) has missing data
# 2012-05-26(index-2702) has missing data
# 2012-05-27(index-2703) has missing data
# 2012-06-02(index-2709) has missing data
# 2012-06-03(index-2710) has missing data
# 2012-06-09(index-2716) has missing data
# 2012-06-10(index-2717) has missing data
# 2012-06-16(index-2723) has missing data
# 2012-06-17(index-2724) has missing data
# 2012-06-22(index-2729) has missing data
# 2012-06-23(index-2730) has missing data
# 2012-06-24(index-2731) has missing data
# 2012-06-30(index-2737) has missing data
# 2012-07-01(index-2738) has missing data
# 2012-07-07(index-2744) has missing data
# 2012-07-08(index-2745) has missing data
# 2012-07-14(index-2751) has missing data
# 2012-07-15(index-2752) has missing data
# 2012-07-21(index-2758) has missing data
# 2012-07-22(index-2759) has missing data
# 2012-07-28(index-2765) has missing data
# 2012-07-29(index-2766) has missing data
# 2012-08-04(index-2772) has missing data
# 2012-08-05(index-2773) has missing data
# 2012-08-11(index-2779) has missing data
# 2012-08-12(index-2780) has missing data
# 2012-08-18(index-2786) has missing data
# 2012-08-19(index-2787) has missing data
# 2012-08-25(index-2793) has missing data
# 2012-08-26(index-2794) has missing data
# 2012-09-01(index-2800) has missing data
# 2012-09-02(index-2801) has missing data
# 2012-09-08(index-2807) has missing data
# 2012-09-09(index-2808) has missing data
# 2012-09-15(index-2814) has missing data
# 2012-09-16(index-2815) has missing data
# 2012-09-22(index-2821) has missing data
# 2012-09-23(index-2822) has missing data
# 2012-09-29(index-2828) has missing data
# 2012-09-30(index-2829) has missing data
# 2012-10-01(index-2830) has missing data
# 2012-10-02(index-2831) has missing data
# 2012-10-03(index-2832) has missing data
# 2012-10-04(index-2833) has missing data
# 2012-10-05(index-2834) has missing data
# 2012-10-06(index-2835) has missing data
# 2012-10-07(index-2836) has missing data
# 2012-10-13(index-2842) has missing data
# 2012-10-14(index-2843) has missing data
# 2012-10-20(index-2849) has missing data
# 2012-10-21(index-2850) has missing data
# 2012-10-27(index-2856) has missing data
# 2012-10-28(index-2857) has missing data
# 2012-11-03(index-2863) has missing data
# 2012-11-04(index-2864) has missing data
# 2012-11-10(index-2870) has missing data
# 2012-11-11(index-2871) has missing data
# 2012-11-17(index-2877) has missing data
# 2012-11-18(index-2878) has missing data
# 2012-11-24(index-2884) has missing data
# 2012-11-25(index-2885) has missing data
# 2012-12-01(index-2891) has missing data
# 2012-12-02(index-2892) has missing data
# 2012-12-08(index-2898) has missing data
# 2012-12-09(index-2899) has missing data
# 2012-12-15(index-2905) has missing data
# 2012-12-16(index-2906) has missing data
# 2012-12-22(index-2912) has missing data
# 2012-12-23(index-2913) has missing data
# 2012-12-29(index-2919) has missing data
# 2012-12-30(index-2920) has missing data
# 2013-01-01(index-2922) has missing data
# 2013-01-02(index-2923) has missing data
# 2013-01-03(index-2924) has missing data
# 2013-01-05(index-2926) has missing data
# 2013-01-06(index-2927) has missing data
# 2013-01-12(index-2933) has missing data
# 2013-01-13(index-2934) has missing data
# 2013-01-19(index-2940) has missing data
# 2013-01-20(index-2941) has missing data
# 2013-01-26(index-2947) has missing data
# 2013-01-27(index-2948) has missing data
# 2013-02-02(index-2954) has missing data
# 2013-02-03(index-2955) has missing data
# 2013-02-09(index-2961) has missing data
# 2013-02-10(index-2962) has missing data
# 2013-02-11(index-2963) has missing data
# 2013-02-12(index-2964) has missing data
# 2013-02-13(index-2965) has missing data
# 2013-02-14(index-2966) has missing data
# 2013-02-15(index-2967) has missing data
# 2013-02-16(index-2968) has missing data
# 2013-02-17(index-2969) has missing data
# 2013-02-23(index-2975) has missing data
# 2013-02-24(index-2976) has missing data
# 2013-03-02(index-2982) has missing data
# 2013-03-03(index-2983) has missing data
# 2013-03-09(index-2989) has missing data
# 2013-03-10(index-2990) has missing data
# 2013-03-16(index-2996) has missing data
# 2013-03-17(index-2997) has missing data
# 2013-03-23(index-3003) has missing data
# 2013-03-24(index-3004) has missing data
# 2013-03-30(index-3010) has missing data
# 2013-03-31(index-3011) has missing data
# 2013-04-04(index-3015) has missing data
# 2013-04-05(index-3016) has missing data
# 2013-04-06(index-3017) has missing data
# 2013-04-07(index-3018) has missing data
# 2013-04-13(index-3024) has missing data
# 2013-04-14(index-3025) has missing data
# 2013-04-20(index-3031) has missing data
# 2013-04-21(index-3032) has missing data
# 2013-04-27(index-3038) has missing data
# 2013-04-28(index-3039) has missing data
# 2013-04-29(index-3040) has missing data
# 2013-04-30(index-3041) has missing data
# 2013-05-01(index-3042) has missing data
# 2013-05-04(index-3045) has missing data
# 2013-05-05(index-3046) has missing data
# 2013-05-11(index-3052) has missing data
# 2013-05-12(index-3053) has missing data
# 2013-05-18(index-3059) has missing data
# 2013-05-19(index-3060) has missing data
# 2013-05-25(index-3066) has missing data
# 2013-05-26(index-3067) has missing data
# 2013-06-01(index-3073) has missing data
# 2013-06-02(index-3074) has missing data
# 2013-06-08(index-3080) has missing data
# 2013-06-09(index-3081) has missing data
# 2013-06-10(index-3082) has missing data
# 2013-06-11(index-3083) has missing data
# 2013-06-12(index-3084) has missing data
# 2013-06-15(index-3087) has missing data
# 2013-06-16(index-3088) has missing data
# 2013-06-22(index-3094) has missing data
# 2013-06-23(index-3095) has missing data
# 2013-06-29(index-3101) has missing data
# 2013-06-30(index-3102) has missing data
# 2013-07-06(index-3108) has missing data
# 2013-07-07(index-3109) has missing data
# 2013-07-13(index-3115) has missing data
# 2013-07-14(index-3116) has missing data
# 2013-07-20(index-3122) has missing data
# 2013-07-21(index-3123) has missing data
# 2013-07-27(index-3129) has missing data
# 2013-07-28(index-3130) has missing data
# 2013-08-03(index-3136) has missing data
# 2013-08-04(index-3137) has missing data
# 2013-08-10(index-3143) has missing data
# 2013-08-11(index-3144) has missing data
# 2013-08-17(index-3150) has missing data
# 2013-08-18(index-3151) has missing data
# 2013-08-24(index-3157) has missing data
# 2013-08-25(index-3158) has missing data
# 2013-08-31(index-3164) has missing data
# 2013-09-01(index-3165) has missing data
# 2013-09-07(index-3171) has missing data
# 2013-09-08(index-3172) has missing data
# 2013-09-14(index-3178) has missing data
# 2013-09-15(index-3179) has missing data
# 2013-09-19(index-3183) has missing data
# 2013-09-20(index-3184) has missing data
# 2013-09-21(index-3185) has missing data
# 2013-09-22(index-3186) has missing data
# 2013-09-28(index-3192) has missing data
# 2013-09-29(index-3193) has missing data
# 2013-10-01(index-3195) has missing data
# 2013-10-02(index-3196) has missing data
# 2013-10-03(index-3197) has missing data
# 2013-10-04(index-3198) has missing data
# 2013-10-05(index-3199) has missing data
# 2013-10-06(index-3200) has missing data
# 2013-10-07(index-3201) has missing data
# 2013-10-12(index-3206) has missing data
# 2013-10-13(index-3207) has missing data
# 2013-10-19(index-3213) has missing data
# 2013-10-20(index-3214) has missing data
# 2013-10-26(index-3220) has missing data
# 2013-10-27(index-3221) has missing data
# 2013-11-02(index-3227) has missing data
# 2013-11-03(index-3228) has missing data
# 2013-11-09(index-3234) has missing data
# 2013-11-10(index-3235) has missing data
# 2013-11-16(index-3241) has missing data
# 2013-11-17(index-3242) has missing data
# 2013-11-23(index-3248) has missing data
# 2013-11-24(index-3249) has missing data
# 2013-11-30(index-3255) has missing data
# 2013-12-01(index-3256) has missing data
# 2013-12-07(index-3262) has missing data
# 2013-12-08(index-3263) has missing data
# 2013-12-14(index-3269) has missing data
# 2013-12-15(index-3270) has missing data
# 2013-12-21(index-3276) has missing data
# 2013-12-22(index-3277) has missing data
# 2013-12-28(index-3283) has missing data
# 2013-12-29(index-3284) has missing data
# 2014-01-01(index-3287) has missing data
# 2014-01-04(index-3290) has missing data
# 2014-01-05(index-3291) has missing data
# 2014-01-11(index-3297) has missing data
# 2014-01-12(index-3298) has missing data
# 2014-01-18(index-3304) has missing data
# 2014-01-19(index-3305) has missing data
# 2014-01-25(index-3311) has missing data
# 2014-01-26(index-3312) has missing data
# 2014-01-31(index-3317) has missing data
# 2014-02-01(index-3318) has missing data
# 2014-02-02(index-3319) has missing data
# 2014-02-03(index-3320) has missing data
# 2014-02-04(index-3321) has missing data
# 2014-02-05(index-3322) has missing data
# 2014-02-06(index-3323) has missing data
# 2014-02-08(index-3325) has missing data
# 2014-02-09(index-3326) has missing data
# 2014-02-15(index-3332) has missing data
# 2014-02-16(index-3333) has missing data
# 2014-02-22(index-3339) has missing data
# 2014-02-23(index-3340) has missing data
# 2014-03-01(index-3346) has missing data
# 2014-03-02(index-3347) has missing data
# 2014-03-08(index-3353) has missing data
# 2014-03-09(index-3354) has missing data
# 2014-03-15(index-3360) has missing data
# 2014-03-16(index-3361) has missing data
# 2014-03-22(index-3367) has missing data
# 2014-03-23(index-3368) has missing data
# 2014-03-29(index-3374) has missing data
# 2014-03-30(index-3375) has missing data
# 2014-04-05(index-3381) has missing data
# 2014-04-06(index-3382) has missing data
# 2014-04-07(index-3383) has missing data
# 2014-04-12(index-3388) has missing data
# 2014-04-13(index-3389) has missing data
# 2014-04-19(index-3395) has missing data
# 2014-04-20(index-3396) has missing data
# 2014-04-26(index-3402) has missing data
# 2014-04-27(index-3403) has missing data
# 2014-05-01(index-3407) has missing data
# 2014-05-02(index-3408) has missing data
# 2014-05-03(index-3409) has missing data
# 2014-05-04(index-3410) has missing data
# 2014-05-10(index-3416) has missing data
# 2014-05-11(index-3417) has missing data
# 2014-05-17(index-3423) has missing data
# 2014-05-18(index-3424) has missing data
# 2014-05-24(index-3430) has missing data
# 2014-05-25(index-3431) has missing data
# 2014-05-31(index-3437) has missing data
# 2014-06-01(index-3438) has missing data
# 2014-06-02(index-3439) has missing data
# 2014-06-07(index-3444) has missing data
# 2014-06-08(index-3445) has missing data
# 2014-06-14(index-3451) has missing data
# 2014-06-15(index-3452) has missing data
# 2014-06-21(index-3458) has missing data
# 2014-06-22(index-3459) has missing data
# 2014-06-28(index-3465) has missing data
# 2014-06-29(index-3466) has missing data
# 2014-07-05(index-3472) has missing data
# 2014-07-06(index-3473) has missing data
# 2014-07-12(index-3479) has missing data
# 2014-07-13(index-3480) has missing data
# 2014-07-19(index-3486) has missing data
# 2014-07-20(index-3487) has missing data
# 2014-07-26(index-3493) has missing data
# 2014-07-27(index-3494) has missing data
# 2014-08-02(index-3500) has missing data
# 2014-08-03(index-3501) has missing data
# 2014-08-09(index-3507) has missing data
# 2014-08-10(index-3508) has missing data
# 2014-08-16(index-3514) has missing data
# 2014-08-17(index-3515) has missing data
# 2014-08-23(index-3521) has missing data
# 2014-08-24(index-3522) has missing data
# 2014-08-30(index-3528) has missing data
# 2014-08-31(index-3529) has missing data
# 2014-09-06(index-3535) has missing data
# 2014-09-07(index-3536) has missing data
# 2014-09-08(index-3537) has missing data
# 2014-09-13(index-3542) has missing data
# 2014-09-14(index-3543) has missing data
# 2014-09-20(index-3549) has missing data
# 2014-09-21(index-3550) has missing data
# 2014-09-27(index-3556) has missing data
# 2014-09-28(index-3557) has missing data
# 2014-10-01(index-3560) has missing data
# 2014-10-02(index-3561) has missing data
# 2014-10-03(index-3562) has missing data
# 2014-10-04(index-3563) has missing data
# 2014-10-05(index-3564) has missing data
# 2014-10-06(index-3565) has missing data
# 2014-10-07(index-3566) has missing data
# 2014-10-11(index-3570) has missing data
# 2014-10-12(index-3571) has missing data
# 2014-10-18(index-3577) has missing data
# 2014-10-19(index-3578) has missing data
# 2014-10-25(index-3584) has missing data
# 2014-10-26(index-3585) has missing data
# 2014-11-01(index-3591) has missing data
# 2014-11-02(index-3592) has missing data
# ...
# 2019-09-29(index-5384) has missing data
# 2019-10-01(index-5386) has missing data
# 2019-10-02(index-5387) has missing data
# 2019-10-03(index-5388) has missing data
# 2019-10-04(index-5389) has missing data
# 2019-10-05(index-5390) has missing data
# 2019-10-06(index-5391) has missing data
# 2019-10-07(index-5392) has missing data
# 2019-10-12(index-5397) has missing data
# 2019-10-13(index-5398) has missing data
# 2019-10-19(index-5404) has missing data
# 2019-10-20(index-5405) has missing data
# 2019-10-26(index-5411) has missing data
# 2019-10-27(index-5412) has missing data
# 2019-11-02(index-5418) has missing data
# 2019-11-03(index-5419) has missing data
# 2019-11-09(index-5425) has missing data
# 2019-11-10(index-5426) has missing data
# 2019-11-16(index-5432) has missing data
# 2019-11-17(index-5433) has missing data
# 2019-11-23(index-5439) has missing data
# 2019-11-24(index-5440) has missing data
# 2019-11-30(index-5446) has missing data
# 2019-12-01(index-5447) has missing data
# 2019-12-07(index-5453) has missing data
# 2019-12-08(index-5454) has missing data
# 2019-12-14(index-5460) has missing data
# 2019-12-15(index-5461) has missing data
# 2019-12-21(index-5467) has missing data
# 2019-12-22(index-5468) has missing data
# 2019-12-28(index-5474) has missing data
# 2019-12-29(index-5475) has missing data
# 2020-01-01(index-5478) has missing data
# 2020-01-04(index-5481) has missing data
# 2020-01-05(index-5482) has missing data
# 2020-01-11(index-5488) has missing data
# 2020-01-12(index-5489) has missing data
# 2020-01-18(index-5495) has missing data
# 2020-01-19(index-5496) has missing data
# 2020-01-24(index-5501) has missing data
# 2020-01-25(index-5502) has missing data
# 2020-01-26(index-5503) has missing data
# 2020-01-27(index-5504) has missing data
# 2020-01-28(index-5505) has missing data
# 2020-01-29(index-5506) has missing data
# 2020-01-30(index-5507) has missing data
# 2020-01-31(index-5508) has missing data
# 2020-02-01(index-5509) has missing data
# 2020-02-02(index-5510) has missing data
# 2020-02-08(index-5516) has missing data
# 2020-02-09(index-5517) has missing data
# 2020-02-15(index-5523) has missing data
# 2020-02-16(index-5524) has missing data
# 2020-02-22(index-5530) has missing data
# 2020-02-23(index-5531) has missing data
# 2020-02-29(index-5537) has missing data
# 2020-03-01(index-5538) has missing data
# 2020-03-07(index-5544) has missing data
# 2020-03-08(index-5545) has missing data
# 2020-03-14(index-5551) has missing data
# 2020-03-15(index-5552) has missing data
# 2020-03-21(index-5558) has missing data
# 2020-03-22(index-5559) has missing data
# 2020-03-28(index-5565) has missing data
# 2020-03-29(index-5566) has missing data
# 2020-04-04(index-5572) has missing data
# 2020-04-05(index-5573) has missing data
# 2020-04-06(index-5574) has missing data
# 2020-04-11(index-5579) has missing data
# 2020-04-12(index-5580) has missing data
# 2020-04-18(index-5586) has missing data
# 2020-04-19(index-5587) has missing data
# 2020-04-25(index-5593) has missing data
# 2020-04-26(index-5594) has missing data
# 2020-05-01(index-5599) has missing data
# 2020-05-02(index-5600) has missing data
# 2020-05-03(index-5601) has missing data
# 2020-05-04(index-5602) has missing data
# 2020-05-05(index-5603) has missing data
# 2020-05-09(index-5607) has missing data
# 2020-05-10(index-5608) has missing data
# 2020-05-16(index-5614) has missing data
# 2020-05-17(index-5615) has missing data
# 2020-05-23(index-5621) has missing data
# 2020-05-24(index-5622) has missing data
# 2020-05-30(index-5628) has missing data
# 2020-05-31(index-5629) has missing data
# 2020-06-06(index-5635) has missing data
# 2020-06-07(index-5636) has missing data
# 2020-06-13(index-5642) has missing data
# 2020-06-14(index-5643) has missing data
# 2020-06-20(index-5649) has missing data
# 2020-06-21(index-5650) has missing data
# 2020-06-25(index-5654) has missing data
# 2020-06-26(index-5655) has missing data
# 2020-06-27(index-5656) has missing data
# 2020-06-28(index-5657) has missing data
# 2020-07-04(index-5663) has missing data
# 2020-07-05(index-5664) has missing data
# 2020-07-11(index-5670) has missing data
# 2020-07-12(index-5671) has missing data
# 2020-07-18(index-5677) has missing data
# 2020-07-19(index-5678) has missing data
# 2020-07-25(index-5684) has missing data
# 2020-07-26(index-5685) has missing data
# 2020-08-01(index-5691) has missing data
# 2020-08-02(index-5692) has missing data
# 2020-08-08(index-5698) has missing data
# 2020-08-09(index-5699) has missing data
# 2020-08-15(index-5705) has missing data
# 2020-08-16(index-5706) has missing data
# 2020-08-22(index-5712) has missing data
# 2020-08-23(index-5713) has missing data
# 2020-08-29(index-5719) has missing data
# 2020-08-30(index-5720) has missing data
# 2020-09-05(index-5726) has missing data
# 2020-09-06(index-5727) has missing data
# 2020-09-12(index-5733) has missing data
# 2020-09-13(index-5734) has missing data
# 2020-09-19(index-5740) has missing data
# 2020-09-20(index-5741) has missing data
# 2020-09-26(index-5747) has missing data
# 2020-09-27(index-5748) has missing data
# 2020-10-01(index-5752) has missing data
# 2020-10-02(index-5753) has missing data
# 2020-10-03(index-5754) has missing data
# 2020-10-04(index-5755) has missing data
# 2020-10-05(index-5756) has missing data
# 2020-10-06(index-5757) has missing data
# 2020-10-07(index-5758) has missing data
# 2020-10-08(index-5759) has missing data
# 2020-10-10(index-5761) has missing data
# 2020-10-11(index-5762) has missing data
# 2020-10-17(index-5768) has missing data
# 2020-10-18(index-5769) has missing data
# 2020-10-24(index-5775) has missing data
# 2020-10-25(index-5776) has missing data
# 2020-10-31(index-5782) has missing data
# 2020-11-01(index-5783) has missing data
# 2020-11-07(index-5789) has missing data
# 2020-11-08(index-5790) has missing data
# 2020-11-14(index-5796) has missing data
# 2020-11-15(index-5797) has missing data
# 2020-11-21(index-5803) has missing data
# 2020-11-22(index-5804) has missing data
# 2020-11-28(index-5810) has missing data
# 2020-11-29(index-5811) has missing data
# 2020-12-05(index-5817) has missing data
# 2020-12-06(index-5818) has missing data
# 2020-12-12(index-5824) has missing data
# 2020-12-13(index-5825) has missing data
# 2020-12-19(index-5831) has missing data
# 2020-12-20(index-5832) has missing data
# 2020-12-26(index-5838) has missing data
# 2020-12-27(index-5839) has missing data
# 2021-01-01(index-5844) has missing data
# 2021-01-02(index-5845) has missing data
# 2021-01-03(index-5846) has missing data
# 2021-01-09(index-5852) has missing data
# 2021-01-10(index-5853) has missing data
# 2021-01-16(index-5859) has missing data
# 2021-01-17(index-5860) has missing data
# 2021-01-23(index-5866) has missing data
# 2021-01-24(index-5867) has missing data
# 2021-01-30(index-5873) has missing data
# 2021-01-31(index-5874) has missing data
# 2021-02-06(index-5880) has missing data
# 2021-02-07(index-5881) has missing data
# 2021-02-11(index-5885) has missing data
# 2021-02-12(index-5886) has missing data
# 2021-02-13(index-5887) has missing data
# 2021-02-14(index-5888) has missing data
# 2021-02-15(index-5889) has missing data
# 2021-02-16(index-5890) has missing data
# 2021-02-17(index-5891) has missing data
# 2021-02-20(index-5894) has missing data
# 2021-02-21(index-5895) has missing data
# 2021-02-27(index-5901) has missing data
# 2021-02-28(index-5902) has missing data
# 2021-03-06(index-5908) has missing data
# 2021-03-07(index-5909) has missing data
# 2021-03-13(index-5915) has missing data
# 2021-03-14(index-5916) has missing data
# 2021-03-20(index-5922) has missing data
# 2021-03-21(index-5923) has missing data
# 2021-03-27(index-5929) has missing data
# 2021-03-28(index-5930) has missing data
# 2021-04-03(index-5936) has missing data
# 2021-04-04(index-5937) has missing data
# 2021-04-05(index-5938) has missing data
# 2021-04-10(index-5943) has missing data
# 2021-04-11(index-5944) has missing data
# 2021-04-17(index-5950) has missing data
# 2021-04-18(index-5951) has missing data
# 2021-04-24(index-5957) has missing data
# 2021-04-25(index-5958) has missing data
# 2021-05-01(index-5964) has missing data
# 2021-05-02(index-5965) has missing data
# 2021-05-03(index-5966) has missing data
# 2021-05-04(index-5967) has missing data
# 2021-05-05(index-5968) has missing data
# 2021-05-08(index-5971) has missing data
# 2021-05-09(index-5972) has missing data
# 2021-05-15(index-5978) has missing data
# 2021-05-16(index-5979) has missing data
# 2021-05-22(index-5985) has missing data
# 2021-05-23(index-5986) has missing data
# 2021-05-29(index-5992) has missing data
# 2021-05-30(index-5993) has missing data
# 2021-06-05(index-5999) has missing data
# 2021-06-06(index-6000) has missing data
# 2021-06-12(index-6006) has missing data
# 2021-06-13(index-6007) has missing data
# 2021-06-14(index-6008) has missing data
# 2021-06-19(index-6013) has missing data
# 2021-06-20(index-6014) has missing data
# 2021-06-26(index-6020) has missing data
# 2021-06-27(index-6021) has missing data
# 2021-07-03(index-6027) has missing data
# 2021-07-04(index-6028) has missing data
# 2021-07-10(index-6034) has missing data
# 2021-07-11(index-6035) has missing data
# 2021-07-17(index-6041) has missing data
# 2021-07-18(index-6042) has missing data
# 2021-07-24(index-6048) has missing data
# 2021-07-25(index-6049) has missing data
# 2021-07-31(index-6055) has missing data
# 2021-08-01(index-6056) has missing data
# 2021-08-07(index-6062) has missing data
# 2021-08-08(index-6063) has missing data
# 2021-08-14(index-6069) has missing data
# 2021-08-15(index-6070) has missing data
# 2021-08-21(index-6076) has missing data
# 2021-08-22(index-6077) has missing data
# 2021-08-28(index-6083) has missing data
# 2021-08-29(index-6084) has missing data
# 2021-09-04(index-6090) has missing data
# 2021-09-05(index-6091) has missing data
# 2021-09-11(index-6097) has missing data
# 2021-09-12(index-6098) has missing data
# 2021-09-18(index-6104) has missing data
# 2021-09-19(index-6105) has missing data
# 2021-09-20(index-6106) has missing data
# 2021-09-21(index-6107) has missing data
# 2021-09-25(index-6111) has missing data
# 2021-09-26(index-6112) has missing data
# 2021-10-01(index-6117) has missing data
# 2021-10-02(index-6118) has missing data
# 2021-10-03(index-6119) has missing data
# 2021-10-04(index-6120) has missing data
# 2021-10-05(index-6121) has missing data
# 2021-10-06(index-6122) has missing data
# 2021-10-07(index-6123) has missing data
# 2021-10-09(index-6125) has missing data
# 2021-10-10(index-6126) has missing data
# 2021-10-16(index-6132) has missing data
# 2021-10-17(index-6133) has missing data
# 2021-10-23(index-6139) has missing data
# 2021-10-24(index-6140) has missing data
# 2021-10-30(index-6146) has missing data
# 2021-10-31(index-6147) has missing data
# 2021-11-06(index-6153) has missing data
# 2021-11-07(index-6154) has missing data
# 2021-11-13(index-6160) has missing data
# 2021-11-14(index-6161) has missing data
# 2021-11-20(index-6167) has missing data
# 2021-11-21(index-6168) has missing data
# 2021-11-27(index-6174) has missing data
# 2021-11-28(index-6175) has missing data
# 2021-12-04(index-6181) has missing data
# 2021-12-05(index-6182) has missing data
# 2021-12-11(index-6188) has missing data
# 2021-12-12(index-6189) has missing data
# 2021-12-18(index-6195) has missing data
# 2021-12-19(index-6196) has missing data
# 2021-12-25(index-6202) has missing data
# 2021-12-26(index-6203) has missing data
# 2022-01-01(index-6209) has missing data
# 2022-01-02(index-6210) has missing data
# 2022-01-03(index-6211) has missing data
# 2022-01-08(index-6216) has missing data
# 2022-01-09(index-6217) has missing data
# 2022-01-15(index-6223) has missing data
# 2022-01-16(index-6224) has missing data
# 2022-01-22(index-6230) has missing data
# 2022-01-23(index-6231) has missing data
# 2022-01-29(index-6237) has missing data
# 2022-01-30(index-6238) has missing data
# 2022-01-31(index-6239) has missing data
# 2022-02-01(index-6240) has missing data
# 2022-02-02(index-6241) has missing data
# 2022-02-03(index-6242) has missing data
# 2022-02-04(index-6243) has missing data
# 2022-02-05(index-6244) has missing data
# 2022-02-06(index-6245) has missing data
# 2022-02-12(index-6251) has missing data
# 2022-02-13(index-6252) has missing data
# 2022-02-19(index-6258) has missing data
# 2022-02-20(index-6259) has missing data
# 2022-02-26(index-6265) has missing data
# 2022-02-27(index-6266) has missing data
# 2022-03-05(index-6272) has missing data
# 2022-03-06(index-6273) has missing data
# 2022-03-12(index-6279) has missing data
# 2022-03-13(index-6280) has missing data
# 2022-03-19(index-6286) has missing data
# 2022-03-20(index-6287) has missing data
# 2022-03-26(index-6293) has missing data
# 2022-03-27(index-6294) has missing data
# 2022-04-02(index-6300) has missing data
# 2022-04-03(index-6301) has missing data
# 2022-04-04(index-6302) has missing data
# 2022-04-05(index-6303) has missing data
# 2022-04-09(index-6307) has missing data
# 2022-04-10(index-6308) has missing data
# 2022-04-16(index-6314) has missing data
# 2022-04-17(index-6315) has missing data
# 2022-04-23(index-6321) has missing data
# 2022-04-24(index-6322) has missing data
# 2022-04-30(index-6328) has missing data
# 2022-05-01(index-6329) has missing data
# 2022-05-02(index-6330) has missing data
# 2022-05-03(index-6331) has missing data
# 2022-05-04(index-6332) has missing data
# 2022-05-07(index-6335) has missing data
# 2022-05-08(index-6336) has missing data
# 2022-05-14(index-6342) has missing data
# 2022-05-15(index-6343) has missing data
# 2022-05-21(index-6349) has missing data
# 2022-05-22(index-6350) has missing data
# 2022-05-28(index-6356) has missing data
# 2022-05-29(index-6357) has missing data
# 2022-06-03(index-6362) has missing data
# 2022-06-04(index-6363) has missing data
# 2022-06-05(index-6364) has missing data
# 2022-06-11(index-6370) has missing data
# 2022-06-12(index-6371) has missing data
# 2022-06-18(index-6377) has missing data
# 2022-06-19(index-6378) has missing data
# 2022-06-25(index-6384) has missing data
# 2022-06-26(index-6385) has missing data
# 2022-07-02(index-6391) has missing data
# 2022-07-03(index-6392) has missing data
# 2022-07-09(index-6398) has missing data
# 2022-07-10(index-6399) has missing data
# 2022-07-16(index-6405) has missing data
# 2022-07-17(index-6406) has missing data
# 2022-07-23(index-6412) has missing data
# 2022-07-24(index-6413) has missing data
# 2022-07-30(index-6419) has missing data
# 2022-07-31(index-6420) has missing data
# 2022-08-06(index-6426) has missing data
# 2022-08-07(index-6427) has missing data
# 2022-08-13(index-6433) has missing data
# 2022-08-14(index-6434) has missing data
# 2022-08-20(index-6440) has missing data
# 2022-08-21(index-6441) has missing data
# 2022-08-27(index-6447) has missing data
# 2022-08-28(index-6448) has missing data
# 2022-09-03(index-6454) has missing data
# 2022-09-04(index-6455) has missing data
# 2022-09-10(index-6461) has missing data
# 2022-09-11(index-6462) has missing data
# 2022-09-12(index-6463) has missing data
# 2022-09-17(index-6468) has missing data
# 2022-09-18(index-6469) has missing data
# 2022-09-24(index-6475) has missing data
# 2022-09-25(index-6476) has missing data
# 2022-10-01(index-6482) has missing data
# 2022-10-02(index-6483) has missing data
# 2022-10-03(index-6484) has missing data
# 2022-10-04(index-6485) has missing data
# 2022-10-05(index-6486) has missing data
# 2022-10-06(index-6487) has missing data
# 2022-10-07(index-6488) has missing data
# 2022-10-08(index-6489) has missing data
# 2022-10-09(index-6490) has missing data
# 2022-10-15(index-6496) has missing data
# 2022-10-16(index-6497) has missing data
# 2022-10-22(index-6503) has missing data
# 2022-10-23(index-6504) has missing data
# 2022-10-29(index-6510) has missing data
# 2022-10-30(index-6511) has missing data
# 2022-11-05(index-6517) has missing data
# 2022-11-06(index-6518) has missing data
# 2022-11-12(index-6524) has missing data
# 2022-11-13(index-6525) has missing data
# 2022-11-19(index-6531) has missing data
# 2022-11-20(index-6532) has missing data
# 2022-11-26(index-6538) has missing data
# 2022-11-27(index-6539) has missing data
# 2022-12-03(index-6545) has missing data
# 2022-12-04(index-6546) has missing data
# 2022-12-10(index-6552) has missing data
# 2022-12-11(index-6553) has missing data
# 2022-12-17(index-6559) has missing data
# 2022-12-18(index-6560) has missing data
# 2022-12-24(index-6566) has missing data
# 2022-12-25(index-6567) has missing data
# 2022-12-31(index-6573) has missing data

# %%
#Handling missing values

#Calculating mean of non-missing values
open_mean = newdf['open'].mean()
close_mean = newdf['close'].mean()
high_mean = newdf['high'].mean()
low_mean = newdf['low'].mean()
volume_mean = newdf['volume(x10^8)'].mean()
money_mean = newdf['money(x10^8)'].mean()
avg_mean = newdf['avg'].mean()
highlimit_mean = newdf['high_limit'].mean()
lowlimit_mean = newdf['low_limit'].mean()
preclose_mean = newdf['pre_close'].mean()
paused_mean = newdf['paused'].mean()
factor_mean = newdf['factor'].mean()

# %%
# Function to insert row in the dataframe
def Insert_row_(row_number, df, row_value):
    # Slice the upper half of the dataframe
    df1 = df[0:row_number]
  
    # Store the result of lower half of the dataframe
    df2 = df[row_number:]
  
    # Insert the row in the upper half dataframe
    df1.loc[row_number]=row_value
  
    # Concat the two dataframes
    df_result = pd.concat([df1, df2])
  
    # Reassign the index labels
    df_result.index = [*range(df_result.shape[0])]
  
    # Return the updated dataframe
    return df_result

record=[]
newdf1 = newdf

for data in msgdata:
    record.append(data[0])
    record.append(open_mean)
    record.append(close_mean)
    record.append(high_mean)
    record.append(low_mean)
    record.append(volume_mean)
    record.append(money_mean)
    record.append(avg_mean)
    record.append(highlimit_mean)
    record.append(lowlimit_mean)
    record.append(preclose_mean)
    record.append(paused_mean)
    record.append(factor_mean)
    newdf1 = Insert_row_(data[1],newdf1,record)
    record=[]

# %%
# Reformatting dates
newdf1['Date'] = pd.to_datetime(newdf1['Date'],format='%Y-%m-%d')
newdf1['Date'] = newdf1['Date'].dt.strftime('%d-%m-%Y')
newdf1.head()
# Out:
#          Date      open     close      high       low  volume(x10^8)  \
# 0  01-01-2005  8.138029  8.146838  8.269845  8.018455       1.110067
# 1  02-01-2005  8.138029  8.146838  8.269845  8.018455       1.110067
# 2  03-01-2005  8.138029  8.146838  8.269845  8.018455       1.110067
# 3  04-01-2005  1.410000  1.400000  1.410000  1.390000       0.082043
# 4  05-01-2005  1.400000  1.390000  1.410000  1.360000       0.150130
#
#    money(x10^8)       avg    high_limit  low_limit  pre_close    paused  \
# 0      9.682490  8.144026  57979.041792   7.348496   8.144223  0.033836
# 1      9.682490  8.144026  57979.041792   7.348496   8.144223  0.033836
# 2      9.682490  8.144026  57979.041792   7.348496   8.144223  0.033836
# 3      0.114656  1.400000      1.560000   1.270000   1.410000  0.000000
# 4      0.207186  1.380000      1.540000   1.260000   1.400000  0.000000
#
#      factor
# 0  0.570852
# 1  0.570852
# 2  0.570852
# 3  0.214624
# 4  0.214624

# %% [markdown]
# ## ii) Checking and Handling Null values

# %%
#Checking for null values
for i in newdf1.columns:
    if(newdf1[i].isnull().sum()!=0):      
        print(f'Column {i} has {newdf1[i].isnull().sum()} null value(s)')
    else:
        print(f'Column {i} has no null value(s)')
# Out:
# Column Date has no null value(s)
# Column open has no null value(s)
# Column close has no null value(s)
# Column high has no null value(s)
# Column low has no null value(s)
# Column volume(x10^8) has no null value(s)
# Column money(x10^8) has no null value(s)
# Column avg has no null value(s)
# Column high_limit has no null value(s)
# Column low_limit has no null value(s)
# Column pre_close has no null value(s)
# Column paused has no null value(s)
# Column factor has no null value(s)

# %%
#Handling null values
for i in newdf1.columns:
    if(newdf1[i].isnull().sum()!=0):      
        for j in range(newdf1.shape[0]):
            if(newdf1[i][j].isna()==True):
                if(i=='open'):
                    newdf1[i][j] = open_mean
                elif(i=='close'):
                    newdf1[i][j] = close_mean
                elif(i=='high'):
                    newdf1[i][j] = high_mean
                elif(i=='low'):
                    newdf1[i][j] = low_mean
                elif(i=='volume(x10^8)'):
                    newdf1[i][j] = volume_mean
                elif(i=='money(x10^8)'):
                    newdf1[i][j] = money_mean
                elif(i=='avg'):
                    newdf1[i][j] = avg_mean
                elif(i=='high_limit'):
                    newdf1[i][j] = highlimit_mean
                elif(i=='low_limit'):
                    newdf1[i][j] = lowlimit_mean
                elif(i=='pre_close'):
                    newdf1[i][j] = preclose_mean
                elif(i=='paused'):
                    newdf1[i][j] = paused_mean
                else:
                    newdf1[i][j] = factor_mean
    else:
        continue
        
newdf1.head()
# Out:
#          Date      open     close      high       low  volume(x10^8)  \
# 0  01-01-2005  8.138029  8.146838  8.269845  8.018455       1.110067
# 1  02-01-2005  8.138029  8.146838  8.269845  8.018455       1.110067
# 2  03-01-2005  8.138029  8.146838  8.269845  8.018455       1.110067
# 3  04-01-2005  1.410000  1.400000  1.410000  1.390000       0.082043
# 4  05-01-2005  1.400000  1.390000  1.410000  1.360000       0.150130
#
#    money(x10^8)       avg    high_limit  low_limit  pre_close    paused  \
# 0      9.682490  8.144026  57979.041792   7.348496   8.144223  0.033836
# 1      9.682490  8.144026  57979.041792   7.348496   8.144223  0.033836
# 2      9.682490  8.144026  57979.041792   7.348496   8.144223  0.033836
# 3      0.114656  1.400000      1.560000   1.270000   1.410000  0.000000
# 4      0.207186  1.380000      1.540000   1.260000   1.400000  0.000000
#
#      factor
# 0  0.570852
# 1  0.570852
# 2  0.570852
# 3  0.214624
# 4  0.214624

# %% [markdown]
# ## iii) Checking duplicate values

# %%
#Checking for duplicate values

#In terms of stock, the values would be duplicates only when date as well as other attributes are same too.
#Same attributes for different dates doesn't imply duplicate values

if(newdf['Date'].duplicated().sum()!=0):      
    print(f'Data set has {newdf[i].duplicated().sum()} duplicate value(s)')
else:
    print('Data set has no duplicate value(s)')
# Out:
# Data set has no duplicate value(s)

# %% [markdown]
# ## iv) Checking garbage values

# %%
#Checking for garbage values
for i in newdf.columns :
    print(newdf[i].value_counts())
    print('//'*10)
# Out:
# 2005-01-04    1
# 2016-12-30    1
# 2017-01-10    1
# 2017-01-09    1
# 2017-01-06    1
#              ..
# 2011-01-12    1
# 2011-01-13    1
# 2011-01-14    1
# 2011-01-17    1
# 2022-12-30    1
# Name: Date, Length: 4374, dtype: int64
# ////////////////////
# 5.39     53
# 1.35     29
# 6.16     28
# 1.24     26
# 4.87     23
#          ..
# 14.97     1
# 5.70      1
# 14.65     1
# 14.39     1
# 12.76     1
# Name: open, Length: 1455, dtype: int64
# ////////////////////
# 5.39     51
# 1.24     27
# 6.16     26
# 1.35     26
# 1.33     22
#          ..
# 15.52     1
# 15.48     1
# 15.43     1
# 9.85      1
# 12.47     1
# Name: close, Length: 1456, dtype: int64
# ////////////////////
# 5.39     51
# 1.35     29
# 6.16     27
# 1.24     23
# 1.37     19
#          ..
# 12.94     1
# 13.70     1
# 13.51     1
# 12.02     1
# 12.73     1
# Name: high, Length: 1457, dtype: int64
# ////////////////////
# 5.39     53
# 1.33     29
# 1.32     26
# 6.16     22
# 1.24     20
#          ..
# 11.10     1
# 10.08     1
# 13.09     1
# 14.90     1
# 12.65     1
# Name: low, Length: 1406, dtype: int64
# ////////////////////
# 0.000000    148
# 0.082043      1
# 0.707695      1
# 0.791016      1
# 0.482501      1
#            ...
# 0.534528      1
# 1.012876      1
# 1.068798      1
# 0.946911      1
# 0.837971      1
# Name: volume(x10^8), Length: 4227, dtype: int64
# ////////////////////
# 0.000000     148
# 0.114656       1
# 6.034501       1
# 6.535338       1
# 3.989866       1
#             ...
# 2.979587       1
# 5.726522       1
# 5.887009       1
# 5.287783       1
# 10.747568      1
# Name: money(x10^8), Length: 4227, dtype: int64
# ////////////////////
# 5.39     52
# 1.33     28
# 6.16     23
# 1.34     22
# 1.24     18
#          ..
# 11.42     1
# 13.09     1
# 11.88     1
# 11.91     1
# 12.66     1
# Name: avg, Length: 1472, dtype: int64
# ////////////////////
# 5.39     47
# 6.16     26
# 1.47     22
# 1.49     21
# 1.46     20
#          ..
# 10.10     1
# 9.94      1
# 8.62      1
# 10.46     1
# 13.72     1
# Name: high_limit, Length: 1541, dtype: int64
# ////////////////////
# 5.39     54
# 7.40     31
# 1.20     27
# 1.21     26
# 6.16     25
#          ..
# 13.25     1
# 13.43     1
# 11.01     1
# 8.90      1
# 11.22     1
# Name: low_limit, Length: 1349, dtype: int64
# ////////////////////
# 5.39     51
# 1.24     27
# 6.16     26
# 1.35     26
# 1.33     22
#          ..
# 15.52     1
# 15.48     1
# 15.43     1
# 9.85      1
# 12.47     1
# Name: pre_close, Length: 1456, dtype: int64
# ////////////////////
# 0    4226
# 1     148
# Name: paused, dtype: int64
# ////////////////////
# 0.307935    965
# 0.214624    592
# 0.236147    335
# 0.958953    290
# 0.737884    289
# 0.898627    268
# 0.501082    238
# 0.911657    238
# 0.951470    233
# 0.925618    231
# 0.935369    224
# 0.609560    203
# 0.310228    158
# 0.976211    110
# Name: factor, dtype: int64
# ////////////////////

# %% [markdown]
# ## v) Extracting required subset of data(8 years data)

# %%
#Extracting required subset of data from dataset

start_index = list(newdf1['Date']).index('01-01-2010')
end_index = list(newdf1['Date']).index('01-01-2018')

temp_date_list = list(newdf1['Date'][start_index:end_index+1])    # List of dates from Jan 1 2010 to Jan 1 2018
#print(temp_date_list)

required_df = newdf1.loc[newdf1['Date'].isin(temp_date_list)]
required_df = required_df.reset_index()
required_df = required_df.drop(columns=['index'])
required_df    #This is our required subset
# Out:
#             Date       open      close       high        low  volume(x10^8)  \
# 0     01-01-2010   8.138029   8.146838   8.269845   8.018455       1.110067
# 1     02-01-2010   8.138029   8.146838   8.269845   8.018455       1.110067
# 2     03-01-2010   8.138029   8.146838   8.269845   8.018455       1.110067
# 3     04-01-2010   7.550000   7.300000   7.570000   7.290000       0.785628
# 4     05-01-2010   7.310000   7.170000   7.360000   7.010000       1.807197
# ...          ...        ...        ...        ...        ...            ...
# 2918  28-12-2017  12.110000  12.040000  12.270000  11.870000       1.703524
# 2919  29-12-2017  12.040000  12.130000  12.240000  11.940000       1.078163
# 2920  30-12-2017   8.138029   8.146838   8.269845   8.018455       1.110067
# 2921  31-12-2017   8.138029   8.146838   8.269845   8.018455       1.110067
# 2922  01-01-2018   8.138029   8.146838   8.269845   8.018455       1.110067
#
#       money(x10^8)        avg    high_limit  low_limit  pre_close    paused  \
# 0         9.682490   8.144026  57979.041792   7.348496   8.144223  0.033836
# 1         9.682490   8.144026  57979.041792   7.348496   8.144223  0.033836
# 2         9.682490   8.144026  57979.041792   7.348496   8.144223  0.033836
# 3         5.802495   7.380000      8.260000   6.750000   7.500000  0.000000
# 4        12.934770   7.160000      8.030000   6.570000   7.300000  0.000000
# ...            ...        ...           ...        ...        ...       ...
# 2918     20.529445  12.050000     13.330000  10.900000  12.120000  0.000000
# 2919     13.032220  12.090000     13.250000  10.840000  12.040000  0.000000
# 2920      9.682490   8.144026  57979.041792   7.348496   8.144223  0.033836
# 2921      9.682490   8.144026  57979.041792   7.348496   8.144223  0.033836
# 2922      9.682490   8.144026  57979.041792   7.348496   8.144223  0.033836
#
#         factor
# 0     0.570852
# 1     0.570852
# 2     0.570852
# 3     0.307935
# 4     0.307935
# ...        ...
# 2918  0.911657
# 2919  0.911657
# 2920  0.570852
# 2921  0.570852
# 2922  0.570852
#
# [2923 rows x 13 columns]

# %% [markdown]
# ## vi) Processing extreme values

# %%
#Handling with outliers(extreme values)

def preprocess_with_dmam_and_zscore(x, n):
    # Calculate the median of the sequence
    xm = np.median(x)
    
    # Calculate the absolute differences from the median
    dm = np.abs(x - xm)
    
    # Calculate the median absolute deviation (DMAD)
    dmad = np.median(dm)
    
    # Calculate z-scores for each value
    z_scores = (x - np.mean(x)) / np.std(x)
    
    processed_x = np.empty_like(x)  # Create an empty array to store processed values
    
    for i, (xi, z_score) in enumerate(zip(x, z_scores)):
        if xi >= xm + n * dmad:
            processed_x[i] = xm + n * dmad
        elif xi <= xm - n * dmad:
            processed_x[i] = xm - n * dmad
        else:
            processed_x[i] = xi
    #print(type(processed_x))
    return processed_x

ppdf = required_df
for col in ppdf:
    if(col=='Date'):
        continue
    else:
        ppdf[col] = preprocess_with_dmam_and_zscore(ppdf[col],1)
ppdf.head()       # We have processed the extreme values
# Out:
#          Date      open     close      high       low  volume(x10^8)  \
# 0  01-01-2010  8.138029  8.146838  8.269845  8.018455       1.110067
# 1  02-01-2010  8.138029  8.146838  8.269845  8.018455       1.110067
# 2  03-01-2010  8.138029  8.146838  8.269845  8.018455       1.110067
# 3  04-01-2010  7.550000  7.300000  7.570000  7.290000       0.819264
# 4  05-01-2010  7.310000  7.290000  7.380000  7.190000       1.400869
#
#    money(x10^8)       avg  high_limit  low_limit  pre_close  paused    factor
# 0      9.682490  8.144026       12.56   7.348496   8.144223     0.0  0.570852
# 1      9.682490  8.144026       12.56   7.348496   8.144223     0.0  0.570852
# 2      9.682490  8.144026       12.56   7.348496   8.144223     0.0  0.570852
# 3      6.341564  7.380000        8.26   6.750000   7.500000     0.0  0.403820
# 4     12.934770  7.288052        8.03   6.576991   7.300000     0.0  0.403820

# %% [markdown]
# ## vii) Creating new column to identify stock trend direction (Target variable)

# %%
no_of_cols = ppdf.shape[0]     #No. of columns
trend_direction=[]
for n in range(no_of_cols):
    i = ppdf['close'][n]
    j = ppdf['pre_close'][n]
    ratio = ((i-j)/j)
    if(ratio>0):
        trend_direction.append(1)
    else:
        trend_direction.append(0)
        
ppdf['Trend Direction'] = trend_direction
ppdf.head()     # This is the preprocessed data set without feature selection
# Out:
#          Date      open     close      high       low  volume(x10^8)  \
# 0  01-01-2010  8.138029  8.146838  8.269845  8.018455       1.110067
# 1  02-01-2010  8.138029  8.146838  8.269845  8.018455       1.110067
# 2  03-01-2010  8.138029  8.146838  8.269845  8.018455       1.110067
# 3  04-01-2010  7.550000  7.300000  7.570000  7.290000       0.819264
# 4  05-01-2010  7.310000  7.290000  7.380000  7.190000       1.400869
#
#    money(x10^8)       avg  high_limit  low_limit  pre_close  paused    factor  \
# 0      9.682490  8.144026       12.56   7.348496   8.144223     0.0  0.570852
# 1      9.682490  8.144026       12.56   7.348496   8.144223     0.0  0.570852
# 2      9.682490  8.144026       12.56   7.348496   8.144223     0.0  0.570852
# 3      6.341564  7.380000        8.26   6.750000   7.500000     0.0  0.403820
# 4     12.934770  7.288052        8.03   6.576991   7.300000     0.0  0.403820
#
#    Trend Direction
# 0                1
# 1                1
# 2                1
# 3                0
# 4                0

# %% [markdown]
# # Feature selection and Dropping irrelevant columns

# %%
#Splitting target class 
X = ppdf.drop(columns=['Trend Direction','Date']) 
y = ppdf['Trend Direction']

#Splitting data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## i) SVM-RFE method

# %%
# SVM-RFE feature selection
def svm_rfe_feature_selection(X, y, n_features_to_select):
    svm = SVC(kernel="linear")
    rfe = RFE(estimator=svm, n_features_to_select=n_features_to_select, step=1)
    rfe.fit(X, y)
    selected_features = X.columns[rfe.support_]
    return selected_features

# Set the number of features to select for SVM-RFE
n_features_to_select_svm = 7
selected_features_svm = svm_rfe_feature_selection(X, y, n_features_to_select_svm)
print("Selected features using SVM-RFE:")
selected_features_svm
# Out:
# Selected features using SVM-RFE:
# Index(['open', 'close', 'high', 'avg', 'low_limit', 'pre_close', 'factor'], dtype='object')

# %%
svmdf = ppdf
svmdf = svmdf.drop(columns=['high','low','volume(x10^8)','money(x10^8)','paused'])
svmdf.head()      # This is the data set for model with SVM-RFE feature selection
# Out:
#          Date      open     close       avg  high_limit  low_limit  pre_close  \
# 0  01-01-2010  8.138029  8.146838  8.144026       12.56   7.348496   8.144223
# 1  02-01-2010  8.138029  8.146838  8.144026       12.56   7.348496   8.144223
# 2  03-01-2010  8.138029  8.146838  8.144026       12.56   7.348496   8.144223
# 3  04-01-2010  7.550000  7.300000  7.380000        8.26   6.750000   7.500000
# 4  05-01-2010  7.310000  7.290000  7.288052        8.03   6.576991   7.300000
#
#      factor  Trend Direction
# 0  0.570852                1
# 1  0.570852                1
# 2  0.570852                1
# 3  0.403820                0
# 4  0.403820                0

# %% [markdown]
# ## ii) RF based Feature Selection method

# %%
# Random Forest-based feature selection
def rf_feature_selection(X, y, threshold):
    rf = RandomForestClassifier(n_estimators=50, random_state=20)
    rf.fit(X, y)
    feature_importances = rf.feature_importances_
    selected_features = X.columns[feature_importances > threshold]
    return selected_features

# Set the threshold for feature selection using Random Forest
threshold_rf = 0.05  # Adjust this threshold as needed
selected_features_rf = rf_feature_selection(X, y, threshold_rf)
print("\nSelected features using Random Forest:")
print(selected_features_rf)
# Out:
# Selected features using Random Forest:
# Index(['open', 'close', 'high', 'low', 'avg', 'high_limit', 'pre_close'], dtype='object')

# %%
rfdf = ppdf
rfdf = rfdf.drop(columns=['factor','low_limit','volume(x10^8)','money(x10^8)','paused'])
rfdf.head()      # This is the data set for model with RF based feature selection
# Out:
#          Date      open     close      high       low       avg  high_limit  \
# 0  01-01-2010  8.138029  8.146838  8.269845  8.018455  8.144026       12.56
# 1  02-01-2010  8.138029  8.146838  8.269845  8.018455  8.144026       12.56
# 2  03-01-2010  8.138029  8.146838  8.269845  8.018455  8.144026       12.56
# 3  04-01-2010  7.550000  7.300000  7.570000  7.290000  7.380000        8.26
# 4  05-01-2010  7.310000  7.290000  7.380000  7.190000  7.288052        8.03
#
#    pre_close  Trend Direction
# 0   8.144223                1
# 1   8.144223                1
# 2   8.144223                1
# 3   7.500000                0
# 4   7.300000                0

# %%
#SVM-RFE feature selection applied training and test sets 
SVM_X = svmdf.drop(columns=['Trend Direction','Date']) 
SVM_y = svmdf['Trend Direction']
SVM_X_train, SVM_X_test, SVM_y_train, SVM_y_test = train_test_split(SVM_X, SVM_y, test_size=0.2)

#RF based feature selection applied training and test sets 
RF_X = rfdf.drop(columns=['Trend Direction','Date']) 
RF_y = rfdf['Trend Direction']
RF_X_train, RF_X_test, RF_y_train, RF_y_test = train_test_split(RF_X, RF_y, test_size=0.2)

# %% [markdown]
# # Training the model and Fitting the data

# %% [markdown]
# ## i) SVM

# %%
#SVM models

svm_model_1 = SVC(kernel='rbf',probability=True) #SVM model trained with data with no feature selection
svm_model_2 = SVC(kernel='rbf',probability=True) #SVM model trained with data with SVM-RFE feature selection
svm_model_3 = SVC(kernel='rbf',probability=True) #SVM model trained with data with RF based feature selection

svm_model_1.fit(X_train, y_train)
svm_model_2.fit(SVM_X_train, SVM_y_train)
svm_model_3.fit(RF_X_train, RF_y_train)

svm_predictions_1 = svm_model_1.predict(X_test)
svm_predictions_2 = svm_model_2.predict(SVM_X_test)
svm_predictions_3 = svm_model_3.predict(RF_X_test)

# %% [markdown]
# ## ii) RF

# %%
#RF models

rf_model_1 = RandomForestClassifier(n_estimators=100, random_state=42) #RF model trained with data with no feature selection
rf_model_2 = RandomForestClassifier(n_estimators=100, random_state=42) #RF model trained with data with SVM-RFE feature selection
rf_model_3 = RandomForestClassifier(n_estimators=100, random_state=42) #RF model trained with data with RF based feature selection

rf_model_1.fit(X_train, y_train)
rf_model_2.fit(SVM_X_train, SVM_y_train)
rf_model_3.fit(RF_X_train, RF_y_train)

rf_predictions_1 = rf_model_1.predict(X_test)
rf_predictions_2 = rf_model_2.predict(SVM_X_test)
rf_predictions_3 = rf_model_3.predict(RF_X_test)

# %% [markdown]
# ## iii) ANN

# %%
#ANN models

X1 = X_train.values  
y1 = y_train.values.reshape(-1, 1)  

X2 = SVM_X_train.values  
y2 = SVM_y_train.values.reshape(-1, 1)  

X3 = RF_X_train.values  
y3 = RF_y_train.values.reshape(-1, 1)  

# ANN model trained with data with no feature selection
nn_model_1 = MLPClassifier(hidden_layer_sizes=(X1.shape[1], X1.shape[1] // 2), activation='logistic', solver='sgd', learning_rate='constant', learning_rate_init=0.1, max_iter=1000)
nn_model_1.fit(X1, y1)

# ANN model trained with data with SVM-RFE feature selection
nn_model_2 = MLPClassifier(hidden_layer_sizes=(X2.shape[1], X2.shape[1] // 2), activation='logistic', solver='sgd', learning_rate='constant', learning_rate_init=0.1, max_iter=1000)
nn_model_2.fit(X2, y2)

# ANN model trained with data with RF based feature selection
nn_model_3 = MLPClassifier(hidden_layer_sizes=(X3.shape[1], X3.shape[1] // 2), activation='logistic', solver='sgd', learning_rate='constant', learning_rate_init=0.1, max_iter=1000)
nn_model_3.fit(X3, y3)


y_pred_nn_1 = nn_model_1.predict(X_test)
y_pred_nn_2 = nn_model_2.predict(SVM_X_test)
y_pred_nn_3 = nn_model_3.predict(RF_X_test)

# %% [markdown]
# # Model evaluation

# %% [markdown]
# ## i) Model without feature selection

# %%
#Models trained with data with no feature selection

print("NO FEATURE SELECTION")

svm_accuracy_1 = accuracy_score(y_test, svm_predictions_1)
print("SVM Model Accuracy:", svm_accuracy_1)

svm_test_proba_1 = svm_model_1.predict_proba(X_test)[:, 1]
svm_auc_1 = roc_auc_score(y_test, svm_test_proba_1)
print("SVM Model ROC AUC Score:", svm_auc_1)

rf_accuracy_1 = accuracy_score(y_test, rf_predictions_1)
print("Random Forest Model Accuracy:", rf_accuracy_1)

rf_test_proba_1 = rf_model_1.predict_proba(X_test)[:, 1]
rf_auc_1 = roc_auc_score(y_test, rf_test_proba_1)
print("Random Forest Model ROC AUC Score:", rf_auc_1)

nn_accuracy_1 = accuracy_score(y_test, np.round(y_pred_nn_1))
print("ANN Model Accuracy:", nn_accuracy_1)

roc_auc_nn_1 = roc_auc_score(y_test, y_pred_nn_1)
print("ANN Model ROC AUC Score:", roc_auc_nn_1)
# Out:
# NO FEATURE SELECTION
# SVM Model Accuracy: 0.9264957264957265
# SVM Model ROC AUC Score: 0.9833302160291779
# Random Forest Model Accuracy: 0.9777777777777777
# Random Forest Model ROC AUC Score: 0.9982874310296456
# ANN Model Accuracy: 0.9145299145299145
# ANN Model ROC AUC Score: 0.9138221266248948

# %% [markdown]
# ## ii) Model with SVM-RFE feature selection

# %%
#Models trained with data with SVM-RFE feature selection

print("SVM-RFE FEATURE SELECTION")

svm_accuracy_2 = accuracy_score(SVM_y_test, svm_predictions_2)
print("SVM Model Accuracy:", svm_accuracy_2)

svm_test_proba_2 = svm_model_2.predict_proba(SVM_X_test)[:, 1]
svm_auc_2 = roc_auc_score(SVM_y_test, svm_test_proba_2)
print("SVM Model ROC AUC Score:", svm_auc_2)

rf_accuracy_2 = accuracy_score(SVM_y_test, rf_predictions_2)
print("Random Forest Model Accuracy:", rf_accuracy_2)

rf_test_proba_2 = rf_model_2.predict_proba(SVM_X_test)[:, 1]
rf_auc_2 = roc_auc_score(SVM_y_test, rf_test_proba_2)
print("Random Forest Model ROC AUC Score:", rf_auc_2)

nn_accuracy_2 = accuracy_score(SVM_y_test, np.round(y_pred_nn_2))
print("ANN Model Accuracy:", nn_accuracy_2)

roc_auc_nn_2 = roc_auc_score(SVM_y_test, y_pred_nn_2)
print("ANN Model ROC AUC Score:", roc_auc_nn_2)
# Out:
# SVM-RFE FEATURE SELECTION
# SVM Model Accuracy: 0.9316239316239316
# SVM Model ROC AUC Score: 0.9903512880562061
# Random Forest Model Accuracy: 0.9811965811965812
# Random Forest Model ROC AUC Score: 0.9989988290398126
# ANN Model Accuracy: 0.9025641025641026
# ANN Model ROC AUC Score: 0.8982142857142857

# %% [markdown]
# ## iii) Model with RF based Feature selection

# %%
#Models trained with data with RF based feature selection

print("RF BASED FEATURE SELECTION")

svm_accuracy_3 = accuracy_score(RF_y_test, svm_predictions_3)
print("SVM Model Accuracy:", svm_accuracy_3)

svm_test_proba_3 = svm_model_3.predict_proba(RF_X_test)[:, 1]
svm_auc_3 = roc_auc_score(RF_y_test, svm_test_proba_3)
print("SVM Model ROC AUC Score:", svm_auc_3)

rf_accuracy_3 = accuracy_score(RF_y_test, rf_predictions_3)
print("Random Forest Model Accuracy:", rf_accuracy_3)

rf_test_proba_3 = rf_model_3.predict_proba(RF_X_test)[:, 1]
rf_auc_3 = roc_auc_score(RF_y_test, rf_test_proba_3)
print("Random Forest Model ROC AUC Score:", rf_auc_3)

nn_accuracy_3 = accuracy_score(RF_y_test, np.round(y_pred_nn_3))
print("ANN Model Accuracy:", nn_accuracy_3)

roc_auc_nn_3 = roc_auc_score(RF_y_test, y_pred_nn_3)
print("ANN Model ROC AUC Score:", roc_auc_nn_3)
# Out:
# RF BASED FEATURE SELECTION
# SVM Model Accuracy: 0.9418803418803419
# SVM Model ROC AUC Score: 0.993932379349046
# Random Forest Model Accuracy: 0.9675213675213675
# Random Forest Model ROC AUC Score: 0.9958964646464648
# ANN Model Accuracy: 0.9145299145299145
# ANN Model ROC AUC Score: 0.9131944444444444

# %% [markdown]
# ## Additional evaluation metrics

# %%
#Additional evaluation metrics defined in base paper

# Function to calculate annualized return
def annualized_return(P, n, Rf, sigma_p):
    Rp = ((1 + P) ** (250 / n) - 1) * 100
    Sharpe = (Rp - Rf) / sigma_p
    return Rp, Sharpe

# Function to calculate win rate
def win_rate(profitable_transactions, total_transactions):
    return profitable_transactions / total_transactions

# Function to calculate profit loss ratio
def profit_loss_ratio(total_profit, total_loss):
    return total_profit / total_loss

# Calculate additional metrics for each model

#NO FETURE SELECTION :-

#SVM :-
svm_ann_return_1, svm_sharpe_ratio_1 = annualized_return(svm_accuracy_1, len(y_test), 0.022, 0.15)
svm_win_rate_1 = win_rate(np.sum(y_test == 1), len(y_test))
svm_profit_loss_ratio_1 = profit_loss_ratio(np.sum(y_test == 1), np.sum(y_test == 0))

#RF :-
rf_ann_return_1, rf_sharpe_ratio_1 = annualized_return(rf_accuracy_1, len(y_test), 0.022, 0.15)
rf_win_rate_1 = win_rate(np.sum(y_test == 1), len(y_test))
rf_profit_loss_ratio_1 = profit_loss_ratio(np.sum(y_test == 1), np.sum(y_test == 0))

#ANN :-
nn_ann_return_1, nn_sharpe_ratio_1 = annualized_return(nn_accuracy_1, len(y_test), 0.022, 0.15)
nn_win_rate_1 = win_rate(np.sum(y_test == 1), len(y_test))
nn_profit_loss_ratio_1 = profit_loss_ratio(np.sum(y_test == 1), np.sum(y_test == 0))

#SVM-RFE FETURE SELECTION :-

#SVM :-
svm_ann_return_2, svm_sharpe_ratio_2 = annualized_return(svm_accuracy_2, len(SVM_y_test), 0.022, 0.15)
svm_win_rate_2 = win_rate(np.sum(SVM_y_test == 1), len(SVM_y_test))
svm_profit_loss_ratio_2 = profit_loss_ratio(np.sum(SVM_y_test == 1), np.sum(SVM_y_test == 0))

#RF :-
rf_ann_return_2, rf_sharpe_ratio_2 = annualized_return(rf_accuracy_2, len(SVM_y_test), 0.022, 0.15)
rf_win_rate_2 = win_rate(np.sum(y_test == 1), len(SVM_y_test))
rf_profit_loss_ratio_2 = profit_loss_ratio(np.sum(SVM_y_test == 1), np.sum(SVM_y_test == 0))

#ANN :-
nn_ann_return_2, nn_sharpe_ratio_2 = annualized_return(nn_accuracy_2, len(SVM_y_test), 0.022, 0.15)
nn_win_rate_2 = win_rate(np.sum(SVM_y_test == 1), len(SVM_y_test))
nn_profit_loss_ratio_2 = profit_loss_ratio(np.sum(SVM_y_test == 1), np.sum(SVM_y_test == 0))

#RF BASED FETURE SELECTION :-

#SVM :-
svm_ann_return_3, svm_sharpe_ratio_3 = annualized_return(svm_accuracy_3, len(RF_y_test), 0.022, 0.15)
svm_win_rate_3 = win_rate(np.sum(RF_y_test == 1), len(RF_y_test))
svm_profit_loss_ratio_3 = profit_loss_ratio(np.sum(RF_y_test == 1), np.sum(RF_y_test == 0))

#RF :-
rf_ann_return_3, rf_sharpe_ratio_3 = annualized_return(rf_accuracy_3, len(RF_y_test), 0.022, 0.15)
rf_win_rate_3 = win_rate(np.sum(RF_y_test == 1), len(RF_y_test))
rf_profit_loss_ratio_3 = profit_loss_ratio(np.sum(RF_y_test == 1), np.sum(RF_y_test == 0))

#ANN :-
nn_ann_return_3, nn_sharpe_ratio_3 = annualized_return(nn_accuracy_3, len(RF_y_test), 0.022, 0.15)
nn_win_rate_3 = win_rate(np.sum(RF_y_test == 1), len(RF_y_test))
nn_profit_loss_ratio_3 = profit_loss_ratio(np.sum(RF_y_test == 1), np.sum(RF_y_test == 0))

print("RESULTS :-")

print("\nANNUALIZED RETURN :-")

print("Of SVM model without feature selection = ",svm_ann_return_1)
print("Of SVM model with SVM-RFE feature selection = ",svm_ann_return_2)
print("Of SVM model with RF based feature selection = ",svm_ann_return_3)

print("\nOf RF model without feature selection = ",rf_ann_return_1)
print("Of RF model with SVM-RFE feature selection = ",rf_ann_return_2)
print("Of RF model with RF based feature selection = ",rf_ann_return_3)

print("\nOf ANN model without feature selection = ",nn_ann_return_1)
print("Of ANN model with SVM-RFE feature selection = ",nn_ann_return_2)
print("Of ANN model with RF based feature selection = ",nn_ann_return_3)

print("\nSHARPE RATIO :-")

print("Of SVM model without feature selection = ",svm_sharpe_ratio_1)
print("Of SVM model with SVM-RFE feature selection = ",svm_sharpe_ratio_2)
print("Of SVM model with RF based feature selection = ",svm_sharpe_ratio_3)

print("\nOf RF model without feature selection = ",rf_sharpe_ratio_1)
print("Of RF model with SVM-RFE feature selection = ",rf_sharpe_ratio_2)
print("Of RF model with RF based feature selection = ",rf_sharpe_ratio_3)

print("\nOf ANN model without feature selection = ",nn_sharpe_ratio_1)
print("Of ANN model with SVM-RFE feature selection = ",nn_sharpe_ratio_2)
print("Of ANN model with RF based feature selection = ",nn_sharpe_ratio_3)

print("\nWIN RATE :-")

print("Of SVM model without feature selection = ",svm_win_rate_1)
print("Of SVM model with SVM-RFE feature selection = ",svm_win_rate_2)
print("Of SVM model with RF based feature selection = ",svm_win_rate_3)

print("\nOf RF model without feature selection = ",rf_win_rate_1)
print("Of RF model with SVM-RFE feature selection = ",rf_win_rate_2)
print("Of RF model with RF based feature selection = ",rf_win_rate_3)

print("\nOf ANN model without feature selection = ",nn_win_rate_1)
print("Of ANN model with SVM-RFE feature selection = ",nn_win_rate_2)
print("Of ANN model with RF based feature selection = ",nn_win_rate_3)

print("\nPROFIT-LOSS RATIO :-")

print("Of SVM model without feature selection = ",svm_profit_loss_ratio_1)
print("Of SVM model with SVM-RFE feature selection = ",svm_profit_loss_ratio_2)
print("Of SVM model with RF based feature selection = ",svm_profit_loss_ratio_3)

print("\nOf RF model without feature selection = ",rf_profit_loss_ratio_1)
print("Of RF model with SVM-RFE feature selection = ",rf_profit_loss_ratio_2)
print("Of RF model with RF based feature selection = ",rf_profit_loss_ratio_3)

print("\nOf ANN model without feature selection = ",nn_profit_loss_ratio_1)
print("Of ANN model with SVM-RFE feature selection = ",nn_profit_loss_ratio_2)
print("Of ANN model with RF based feature selection = ",nn_profit_loss_ratio_3)
# Out:
# RESULTS :-
#
# ANNUALIZED RETURN :-
# Of SVM model without feature selection =  32.341407083330395
# Of SVM model with SVM-RFE feature selection =  32.49184127430329
# Of SVM model with RF based feature selection =  32.79202500824332
#
# Of RF model without feature selection =  33.835577779029435
# Of RF model with SVM-RFE feature selection =  33.934396117567054
# Of RF model with RF based feature selection =  33.53853449080919
#
# Of ANN model without feature selection =  31.98949984118895
# Of ANN model with SVM-RFE feature selection =  31.636330834788893
# Of ANN model with RF based feature selection =  31.98949984118895
#
# SHARPE RATIO :-
# Of SVM model without feature selection =  215.46271388886933
# Of SVM model with SVM-RFE feature selection =  216.4656084953553
# Of SVM model with RF based feature selection =  218.46683338828882
#
# Of RF model without feature selection =  225.42385186019627
# Of RF model with SVM-RFE feature selection =  226.0826407837804
# Of RF model with RF based feature selection =  223.44356327206128
#
# Of ANN model without feature selection =  213.11666560792636
# Of ANN model with SVM-RFE feature selection =  210.7622055652593
# Of ANN model with RF based feature selection =  213.11666560792636
#
# WIN RATE :-
# Of SVM model without feature selection =  0.49401709401709404
# Of SVM model with SVM-RFE feature selection =  0.5213675213675214
# Of SVM model with RF based feature selection =  0.49230769230769234
#
# Of RF model without feature selection =  0.49401709401709404
# Of RF model with SVM-RFE feature selection =  0.49401709401709404
# Of RF model with RF based feature selection =  0.49230769230769234
#
# Of ANN model without feature selection =  0.49401709401709404
# Of ANN model with SVM-RFE feature selection =  0.5213675213675214
# Of ANN model with RF based feature selection =  0.49230769230769234
#
# PROFIT-LOSS RATIO :-
# Of SVM model without feature selection =  0.9763513513513513
# Of SVM model with SVM-RFE feature selection =  1.0892857142857142
# Of SVM model with RF based feature selection =  0.9696969696969697
#
# Of RF model without feature selection =  0.9763513513513513
# Of RF model with SVM-RFE feature selection =  1.0892857142857142
# Of RF model with RF based feature selection =  0.9696969696969697
#
# Of ANN model without feature selection =  0.9763513513513513
# Of ANN model with SVM-RFE feature selection =  1.0892857142857142
# Of ANN model with RF based feature selection =  0.9696969696969697
